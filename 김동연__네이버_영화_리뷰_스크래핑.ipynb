# %% [markdown]
# <a href="https://colab.research.google.com/github/tjy2202/Personal_training/blob/main/%EA%B9%80%EB%8F%99%EC%97%B0__%EB%84%A4%EC%9D%B4%EB%B2%84_%EC%98%81%ED%99%94_%EB%A6%AC%EB%B7%B0_%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BeautyfulSoup 네이버 영화 리뷰 스크래핑

# %% [markdown]
# ## 네이버 영화 리뷰 스크래핑
#
# * 네이버 영화: https://movie.naver.com/movie/point/af/list.nhn

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import pandas as pd

def get_movie_reviews(mcode, page_num=10):
  
  movie_review_df = pd.DataFrame(columns=('Ttile','Score','Review'))
  url ='https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=' + str(mcode) + '&target=after'
  idx = 0
  for _ in range(0, page_num):
    movie_page = urllib.request.urlopen(url).read()
    movie_page_soup = BeautifulSoup(movie_page,'html.parser')
    
    review_list = movie_page_soup.find_all('td',{'class':'title'})
    for review in review_list:
      title = review.find('a',{'class':'movie color_b'}).get_text()
      score = review.find('em').get_text()
      review_text = review.find('a',{'class':'report'}).get('href').split(',')[2]
      movie_review_df.loc[idx] = [title,score,review_text]
      idx += 1
      print('#',end='')

    try:
      url = 'https://movie.naver.com' + movie_page_soup.find('a',{'class':'pg_next'}).get('href')
    except:
      break

  return movie_review_df

# %%
movie_review_df = get_movie_reviews(189537,3)
movie_review_df
# Out:
# ##############################
#     Ttile Score                                             Review
# 0   #살아있다     4                                 '인랑과 비슷한 느낌을 받았어요'
# 1   #살아있다    10   '다들  개연성따지냐평소얼마나논리적으로사냐영화 그냥 재미나게봐.개연성논리따질거면 ...
# 2   #살아있다     1               '홍보할라고 나혼산 나오고 별 지랄 염병을 떨었지만 어림도없지ㅋ'
# 3   #살아있다     8                                      '정말볼만한영화였습니다'
# 4   #살아있다     2   '좀비된 아내 멕일려고 멀쩡한사람 먹게 하는거 진짜 어이가 없다ㅋ 그럴거면 지가 ...
# 5   #살아있다     8                      '그냥 타임킬링용으로 딱 좋음. 가볍게 보면 볼만함'
# 6   #살아있다     1                                                 ''
# 7   #살아있다    10                                                 ''
# 8   #살아있다     1                                    '평점이 왜 이렇게 높죠?'
# 9   #살아있다     4   '간만에 보는 망작이다...좀비영화를 이렇게 만들수가...소리만 지르면 몇동 몇호...
# 10  #살아있다     8                         '난 재밌긴 재밌음 근데 개연성이 너무 허접함'
# 11  #살아있다     1       '뭐냐고요...집에서 포인로11000넌 내고 봤는데.. 아깝단 생각이 듭니다.'
# 12  #살아있다     2                            '영화 끝나고 살아있는 내가 더 재밌는듯'
# 13  #살아있다     2                        '유아인배우님 박신혜배우님..고생많으셨습니다..'
# 14  #살아있다     1   '그냥 쓰레기 영화구여..감독 누군지볼려했는데 이미지 준비중이네요 ㅋ감독님도 얼굴...
# 15  #살아있다     2                             '너 연막탄오디서낫니? 드라이아이스니?'
# 16  #살아있다     1                      '평점 살면서 처음남겨봄 본 영화중 제일 재미없음 '
# 17  #살아있다     1                                    '이건 1점도 아깝다...'
# 18  #살아있다     2                                  '십노잼 개노잼 쌉노잼 걍노잼'
# 19  #살아있다     7   '저는 생각보다는 재미있게 봤어요 ㅎㅎ 월드Z같은걸 기대한게 아니라서.. 박신혜 ...
# 20  #살아있다     1                                               '최악'
# 21  #살아있다     8                              '평점이 별로라서 보지 않으려고 하다가
# 22  #살아있다     1   '와 개연성 씹창나네 그리고 어떤새끼가 지 죽을지도모르는데 화분에 물을쳐주냐 그리...
# 23  #살아있다     2                                   '예고편만봐도 알수있음 이제'
# 24  #살아있다     1                                   '최악이에요 넘나 와 진심 '
# 25  #살아있다     3   '와~~!! 요근래 본 영화중 최고네요..울 조카가 시나리오 써도 이것보다 잘 썼...
# 26  #살아있다     2   '진짜 개노잼이요 보는데 고구마 한 100먹은듯 생각없이 행동하고 그리고 어떻게든...
# 27  #살아있다     8                      '생각보다 재밌던데 왜케 욕을 먹는거지? 알바들인가'
# 28  #살아있다     5               '그냥 딱 킬링타임용이에요. 근데 이거 웹툰 영화화한 건가요? '
# 29  #살아있다     6                                    '집문을 고쳐야하는 영화 '

# %% [markdown]
# ## 현재상영작 영화 리뷰 스크래핑

# %%
url = 'https://movie.naver.com/movie/point/af/list.nhn'
naver_movie = urllib.request.urlopen(url).read()
soup = BeautifulSoup(naver_movie,'html.parser')
select = soup.find('select',{'id':'current_movie'})
movies = select.find_all('option')

movies_dict = {}

for movie in movies[1:]:
  movies_dict[movie.get('value')] = movie.get_text()

movie_review_df = pd.DataFrame(columns=('Ttile','Score','Review'))
for mcode in movies_dict:
  df = get_movie_reviews(mcode,1)
  movie_review_df = pd.concat([movie_review_df,df])

movie_review_df
# Out:
# ###################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################
#           Ttile Score                                             Review
# 0   주식회사 스페셜액터스     8   '기대하고 보지않은 영화였는데 뒤로 갈수록 스토리에 빠지는 감동까지 있는 재미있는...
# 1   주식회사 스페셜액터스     1                                    '평점에 속지말라 !!!!'
# 2   주식회사 스페셜액터스    10   '전작인 카멈처럼 신선하진 않았지만 예측 가능한 스토리를 충분히 즐겁게 볼 수 있...
# 3   주식회사 스페셜액터스     9                                  '반전의 반전의 반전 ㄷㄷㄷㄷ'
# 4   주식회사 스페셜액터스     9                '마지막감동..간만에 본 영화인데 시간과 돈이 아깝지 않았네요'
# ..          ...   ...                                                ...
# 2      말 없는 사나이    10   '왜 재밌는지 모르게 재밌다. 특히나 자전거 데이트씬은 근래 보았던 어떤 최신멜로...
# 3      말 없는 사나이     7                                     '나는 희극이 별로에요.'
# 4      말 없는 사나이    10            '&amp;#34;말 없는 사나이&amp;#34;는 서부 영화 제목같고
# 5      말 없는 사나이     1                                    '내가본것중최악 시간아깝다'
# 6      말 없는 사나이    10   '&amp;#39;아일랜드 기질&amp;#39;이 뭔지를 확실히 보여주는 코미디....
#
# [1427 rows x 3 columns]
