# %% [markdown]
# # 파이토치 MNIST 모델

# %% [markdown]
# ## modules import

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.datasets
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %% [markdown]
# ## 전처리 설정
# - `transform.Compose`

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,),(0.5,))])

# %% [markdown]
# ## 데이터 로드 및 데이터 확인

# %%
trainset = torchvision.datasets.MNIST(root='./data',
                                      train=True,
                                      download=True,
                                      transform=transform)
testset = torchvision.datasets.MNIST(root='./data',
                                      train=False,
                                      download=True,
                                      transform=transform)

# %%
train_loader = DataLoader(trainset,
                          batch_size=128,
                          shuffle=True,
                          num_workers=2)
test_loader = DataLoader(testset,
                          batch_size=128,
                          shuffle=False,
                          num_workers=2)

# %%
image, label = next(iter(train_loader))

# %%
image.shape, label.shape
# Out:
# (torch.Size([128, 1, 28, 28]), torch.Size([128]))

# %%
def imshow(img):
  img = img / 2 +0.5
  npimg = img.numpy()
  fig = plt.figure(figsize=(10,5))
  plt.imshow(np.transpose(npimg,(1,2,0)))
  plt.show()

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()
imshow(torchvision.utils.make_grid(images[:4]))

# %% [markdown]
# ## 신경망 구성

# %%
class Net(nn.Module):

  def __init__(self):
    super(Net, self).__init__()
    
    self.conv1 = nn.Conv2d(1,6,3)
    self.conv2 = nn.Conv2d(6,16,3)

    self.fc1 = nn.Linear(16 * 5 * 5, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    x = F.max_pool2d(F.relu(self.conv1(x)), (2,2))
    x = F.max_pool2d(F.relu(self.conv2(x)), 2)
    x = x.view(-1, self.num_flat_features(x))
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x

  def num_flat_features(self, x):
    size = x.size()[1:]
    num_features = 1
    for s in size:
      num_features *= s

    return num_features

net = Net()
print(net)
# Out:
# Net(
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %% [markdown]
# - `.parameters()`

# %%
params = list(net.parameters())
print(len(params))
print(params[0].size())
# Out:
# 10
# torch.Size([6, 1, 3, 3])

# %% [markdown]
# 임의의 값을 넣어 forward값 확인

# %%
input = torch.randn(1,1,28,28)
out = net(input)
print(out)
# Out:
# tensor([[-0.0112, -0.0069,  0.0858,  0.0216,  0.0376,  0.0757, -0.0013, -0.1004,
#           0.0343,  0.1032]], grad_fn=<AddmmBackward>)

# %% [markdown]
# ## 손실함수와 옵티마이저

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)#SGD 가 momentum으로 실행

# %% [markdown]
# ## 모델 학습
#
# - `optimizer.zero_grad` : 가중치의 그래디언트 초기화
#
# - loss 계산
#
# - `loss.backward()`
#
# - `optmizer.step()` : 업데이트

# %% [markdown]
# - 배치수 확인

# %%
total_batch = len(train_loader)
print(total_batch)
# Out:
# 469

# %% [markdown]
# - 설명을 위해 `epochs=2`로 지정

# %%
for epoch in range(2):
  running_loss = 0.0
  for i, data in enumerate(train_loader, 0):
    inputs, labels = data
    optimizer.zero_grad()
    outputs = net(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    running_loss += loss.item()
    if i % 100 == 99:
      print('Epoch: {}, Iter: {}, Loss: {}'.format(epoch+1, i+1, running_loss/2000))
      running_loss = 0.0
# Out:
# Epoch: 1, Iter: 100, Loss: 0.11510644888877869
# Epoch: 1, Iter: 200, Loss: 0.11482643568515778
# Epoch: 1, Iter: 300, Loss: 0.11454395759105683
# Epoch: 1, Iter: 400, Loss: 0.11414318227767944
# Epoch: 2, Iter: 100, Loss: 0.11278433859348297
# Epoch: 2, Iter: 200, Loss: 0.11093098247051239
# Epoch: 2, Iter: 300, Loss: 0.10639390873908997
# Epoch: 2, Iter: 400, Loss: 0.09267786872386932

# %% [markdown]
# ## 모델의 저장 및 로드
#
# - `torch.save`
#   - `net.state_dict()`를 저장
#
# - `torch.load`
#   - `load_state_dict`로 모델을 로드

# %%
PATH = './mnist_net.pth'
torch.save(net.state_dict(), PATH)

# %%
net = Net()
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
net.parameters
# Out:
# <bound method Module.parameters of Net(
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )>

# %% [markdown]
# ## 모델 테스트

# %%
dataiter = iter(test_loader)
images, labels = dataiter.next()

imshow(torchvision.utils.make_grid(images[:4]))

# %%
outputs = net(images)

# %%
_, predicted = torch.max(outputs, 1)
print(predicted)
# Out:
# tensor([7, 2, 1, 0, 4, 1, 7, 9, 6, 7, 0, 6, 4, 0, 1, 5, 4, 7, 3, 4, 7, 6, 4, 5,
#         4, 0, 7, 4, 0, 1, 3, 1, 3, 0, 7, 2, 7, 1, 2, 1, 1, 7, 4, 1, 3, 5, 3, 2,
#         4, 4, 6, 3, 5, 5, 2, 0, 4, 1, 4, 8, 7, 2, 4, 3, 7, 9, 4, 4, 3, 0, 7, 0,
#         2, 8, 1, 7, 3, 7, 1, 7, 7, 6, 2, 7, 4, 4, 7, 5, 6, 1, 3, 6, 7, 3, 1, 4,
#         1, 7, 6, 4, 6, 0, 5, 4, 4, 4, 0, 1, 9, 4, 8, 1, 3, 7, 7, 4, 7, 4, 7, 9,
#         5, 4, 7, 6, 7, 9, 5, 5])

# %%
print(''.join('{}\t'.format(str(predicted[j].numpy())) for j in range(4)))
# Out:
# 7	2	1	0

# %%
correct = 0
total = 0

with torch.no_grad():
  for data in test_loader:
    images, labels = data
    outputs = net(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()

print(100 * correct / total)
# Out:
# 69.51

# %% [markdown]
# ## GPU 설정 후 학습
# - 설정 후, 모델과 데이터에 `to`로 GPU를 사용 가능한 형태로 변환 해줘야 한다.
#
# - `.cuda()` 로도 가능

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.datasets
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %% [markdown]
# - 현재 GPU 설정

# %%
torch.cuda.is_available()
# Out:
# True

# %%
use_cuda = torch.cuda.is_available()
device = torch.device('cuda' if use_cuda else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# - 데이터 로드

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,),(0.5,))])

trainset = torchvision.datasets.MNIST(root='./data',
                                      train=True,
                                      download=True,
                                      transform=transform)
testset = torchvision.datasets.MNIST(root='./data',
                                      train=False,
                                      download=True,
                                      transform=transform)

train_loader = DataLoader(trainset,
                          batch_size=128,
                          shuffle=True,
                          num_workers=2)
test_loader = DataLoader(testset,
                          batch_size=128,
                          shuffle=False,
                          num_workers=2)

# %% [markdown]
# - 모델 생성

# %%
class Net(nn.Module):

  def __init__(self):
    super(Net, self).__init__()
    
    self.conv1 = nn.Conv2d(1,6,3)
    self.conv2 = nn.Conv2d(6,16,3)

    self.fc1 = nn.Linear(16 * 5 * 5, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    x = F.max_pool2d(F.relu(self.conv1(x)), (2,2))
    x = F.max_pool2d(F.relu(self.conv2(x)), 2)
    x = x.view(-1, self.num_flat_features(x))
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x

  def num_flat_features(self, x):
    size = x.size()[1:]
    num_features = 1
    for s in size:
      num_features *= s

    return num_features

net = Net()
print(net)
# Out:
# Net(
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
net = Net().to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)#SGD 가 momentum으로 실행

# %%
for epoch in range(2):
  running_loss = 0.0
  for i, data in enumerate(train_loader, 0):
    inputs, labels = data[0].to(device), data[1].to(device)
    optimizer.zero_grad()
    outputs = net(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    running_loss += loss.item()
    if i % 100 == 99:
      print('Epoch: {}, Iter: {}, Loss: {}'.format(epoch+1, i+1, running_loss/2000))
      running_loss = 0.0
# Out:
# Epoch: 1, Iter: 100, Loss: 0.11497797060012817
# Epoch: 1, Iter: 200, Loss: 0.11457234537601471
# Epoch: 1, Iter: 300, Loss: 0.11413950645923615
# Epoch: 1, Iter: 400, Loss: 0.1134754902124405
# Epoch: 2, Iter: 100, Loss: 0.11096631801128387
# Epoch: 2, Iter: 200, Loss: 0.10625666427612304
# Epoch: 2, Iter: 300, Loss: 0.09297299271821975
# Epoch: 2, Iter: 400, Loss: 0.06614104548096657

# %%
correct = 0
total = 0

with torch.no_grad():
  for data in test_loader:
    images, labels = data[0].to(device), data[1].to(device)
    outputs = net(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()

print(100 * correct / total)
# Out:
# 79.49
