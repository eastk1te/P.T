# %% [markdown]
# # 입력과 출력

# %% [markdown]
# ---

# %% [markdown]
# ## 표준 입출력(Standard Input/Output)

# %% [markdown]
# ### 표준 입력 함수

# %%
name = input("이름 : ")
print(name)
# Out:
# 이름 : Steve
# Steve

# %% [markdown]
# #### [Lab] 섭씨 온도를 화씨 온도로 변환
#
# * 섭씨 온도를 화씨 온도로 변환하는 공식: $F = (C * 1.8) + 32$

# %%
C = float(input("온도"))
F = C*1.8 + 32
print(F)
# Out:
# 온도20
# 68.0

# %% [markdown]
# #### [Lab] 구구단 중의 하나의 단을 입력받아 계산
#
# * 출력할 단을 입력
# * 해당 단의 계산 결과 출력

# %%
i = int(input("출력할 단 : "))
for j in range(1,10):
  print('{0} x {1} = {2}'.format(i,j,i*j))
# Out:
# 출력할 단 : 9
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81

# %% [markdown]
# ### 표준 출력 함수

# %%
print('hellow world')
print('안녕 파이썬')
print(7)
print(3.14)

print("hello","world", sep = "---")
print(1,2,3)
print(1,end=' ')

print(2,end=' ')
print(3,end=' ')
# Out:
# hellow world
# 안녕 파이썬
# 7
# 3.14
# hello---world
# 1 2 3
# 1 2 3

# %% [markdown]
# #### [Lab] 구구단 출력
#
# * `print()` 함수를 사용하여 각 단마다 횡으로 출력

# %%
for i in range(2,10):
  for j in range(1,10):
    print('{0} x {1} = {2}'.format(i,j,i*j), end = '\t')
  print()
# Out:
# 2 x 1 = 2	2 x 2 = 4	2 x 3 = 6	2 x 4 = 8	2 x 5 = 10	2 x 6 = 12	2 x 7 = 14	2 x 8 = 16	2 x 9 = 18
# 3 x 1 = 3	3 x 2 = 6	3 x 3 = 9	3 x 4 = 12	3 x 5 = 15	3 x 6 = 18	3 x 7 = 21	3 x 8 = 24	3 x 9 = 27
# 4 x 1 = 4	4 x 2 = 8	4 x 3 = 12	4 x 4 = 16	4 x 5 = 20	4 x 6 = 24	4 x 7 = 28	4 x 8 = 32	4 x 9 = 36
# 5 x 1 = 5	5 x 2 = 10	5 x 3 = 15	5 x 4 = 20	5 x 5 = 25	5 x 6 = 30	5 x 7 = 35	5 x 8 = 40	5 x 9 = 45
# 6 x 1 = 6	6 x 2 = 12	6 x 3 = 18	6 x 4 = 24	6 x 5 = 30	6 x 6 = 36	6 x 7 = 42	6 x 8 = 48	6 x 9 = 54
# 7 x 1 = 7	7 x 2 = 14	7 x 3 = 21	7 x 4 = 28	7 x 5 = 35	7 x 6 = 42	7 x 7 = 49	7 x 8 = 56	7 x 9 = 63
# 8 x 1 = 8	8 x 2 = 16	8 x 3 = 24	8 x 4 = 32	8 x 5 = 40	8 x 6 = 48	8 x 7 = 56	8 x 8 = 64	8 x 9 = 72
# 9 x 1 = 9	9 x 2 = 18	9 x 3 = 27	9 x 4 = 36	9 x 5 = 45	9 x 6 = 54	9 x 7 = 63	9 x 8 = 72	9 x 9 = 81

# %% [markdown]
# ---

# %% [markdown]
# ## 파일 입출력(File Input/Output)

# %% [markdown]
# ### 파일 입출력 과정
#
# * 파일의 입출력 과정은 단계를 가짐
# * 파일을 열고, 파일을 읽거나 쓰고, 파일을 닫는 순서

# %% [markdown]
# ### 파일 열기/닫기
#
# * file.txt 파일을 생성하고, 열고 닫기

# %%
f = open('file.txt', 'w')
f = open('file.txt', 'r')
f.close()

# %%
# !ls file.txt
# Out:
# file.txt

# %% [markdown]
# ### 파일 모드(File Mode)

# %% [markdown]
# ### 텍스트 파일 쓰기

# %% [markdown]
# #### write()
#
# * `write()`를 이용하여 파일에 쓰기

# %%
f = open('file.txt', 'w')
f.write('Hello World')
f.close()

# %%
# !cat file.txt
# Out:
# Hello World

# %% [markdown]
# #### writelines()
#
# * `writelines()`를 이용하여 list를 파일에 쓰기

# %%
list = ['one\n','two\n','three\n']
f = open('file.txt', 'w')
f.writelines(list)
f.close()

# %%
# !cat file.txt
# Out:
# one
# two
# three

# %% [markdown]
# #### 표준 입력 → 파일 쓰기
#
# * 표준 입력을 `input()` 함수를 통해 입력 받고, `write()` 함수를 통해 파일에 쓰기

# %%
text = input('입력 : ')
f = open('file.txt','w')
f.write(text)
f.close()
# Out:
# 입력 : dong

# %%
# !cat file.txt
# Out:
# dong

# %%
text = [str(text + '\n') for text in input("여러 값 입력: ").split()]
f = open('file.txt','w')
f.writelines(text)
f.close()
# Out:
# 여러 값 입력: 1 2 3 4 5 6

# %%
# !cat file.txt
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
x = ''
text = ""
while x != 'q':
  x = input("반복 입력 : ")
  text += x + '\n'

f= open('file.txt','w')
f.writelines(text)
f.close()
# Out:
# 반복 입력 : 1
# 반복 입력 :
# 반복 입력 : 3
# 반복 입력 : 4
# 반복 입력 : 5
# 반복 입력 : q

# %%
# !cat file.txt
# Out:
# 1
#
# 3
# 4
# 5
# q

# %% [markdown]
# ### [Lab] 구구단 결과를 파일에 쓰기
#
# * 구구단 결과를 파일에 쓰기

# %%
f = open('dan.txt','w')
for i in range(2,10):
  for j in range(1,10):
    f.write('{0} x {1} = {2}\t'.format(i,j,i*j))
  else:
    f.write('\n')

f.close()

# %%
# !cat dan.txt
# Out:
# 2 x 1 = 2	2 x 2 = 4	2 x 3 = 6	2 x 4 = 8	2 x 5 = 10	2 x 6 = 12	2 x 7 = 14	2 x 8 = 16	2 x 9 = 18
# 3 x 1 = 3	3 x 2 = 6	3 x 3 = 9	3 x 4 = 12	3 x 5 = 15	3 x 6 = 18	3 x 7 = 21	3 x 8 = 24	3 x 9 = 27
# 4 x 1 = 4	4 x 2 = 8	4 x 3 = 12	4 x 4 = 16	4 x 5 = 20	4 x 6 = 24	4 x 7 = 28	4 x 8 = 32	4 x 9 = 36
# 5 x 1 = 5	5 x 2 = 10	5 x 3 = 15	5 x 4 = 20	5 x 5 = 25	5 x 6 = 30	5 x 7 = 35	5 x 8 = 40	5 x 9 = 45
# 6 x 1 = 6	6 x 2 = 12	6 x 3 = 18	6 x 4 = 24	6 x 5 = 30	6 x 6 = 36	6 x 7 = 42	6 x 8 = 48	6 x 9 = 54
# 7 x 1 = 7	7 x 2 = 14	7 x 3 = 21	7 x 4 = 28	7 x 5 = 35	7 x 6 = 42	7 x 7 = 49	7 x 8 = 56	7 x 9 = 63
# 8 x 1 = 8	8 x 2 = 16	8 x 3 = 24	8 x 4 = 32	8 x 5 = 40	8 x 6 = 48	8 x 7 = 56	8 x 8 = 64	8 x 9 = 72
# 9 x 1 = 9	9 x 2 = 18	9 x 3 = 27	9 x 4 = 36	9 x 5 = 45	9 x 6 = 54	9 x 7 = 63	9 x 8 = 72	9 x 9 = 81

# %% [markdown]
# ### 텍스트 파일 출력

# %% [markdown]
# * 텍스트 파일 예제

# %%
# !echo "동해물과 백두산이 마르고 닳도록" > anthem.txt
# !echo "하느님이 보우하사 우리나라 만세" >> anthem.txt

# %% [markdown]
#  >>antehm
# #### readline()
#
# * `readline()`를 이용하여 텍스트 파일을 라인 단위로 읽고 화면에 출력

# %%
f = open('anthem.txt', 'r')
while True:
  line = f.readline()
  if not line: break
  print(line)
  
f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
#
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# #### readlines()
#
# * `readlines()`를 이용하여 텍스트 파일의 여러 라인을 읽고 화면에 출력

# %%
f = open('anthem.txt','r')
lines = f.readlines()
print(lines)
f.close()
# Out:
# ['동해물과 백두산이 마르고 닳도록\n', '하느님이 보우하사 우리나라 만세\n']

# %% [markdown]
# #### read()
#
# * `read()`를 이용하여 텍스트 파일을 읽고 화면에 출력

# %%
f = open('anthem.txt','r')
data = f.read()
print(data)
f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# #### tell()
#
# * 파일 포인터 위치 변경

# %%
f = open('anthem.txt','r')
while True:
  print(f.tell())
  line = f.readline()
  if not line: break
  print(line)
f.close()
# Out:
# 0
# 동해물과 백두산이 마르고 닳도록
#
# 46
# 하느님이 보우하사 우리나라 만세
#
# 92

# %% [markdown]
# #### seek()
#
# * 파일 포인터 위치 이동

# %%
f = open('anthem.txt','r')
f.seek(6)
line = f.readline()
print(line)
f.seek(46)
line = f.readline()
print(line)
f.close()
# Out:
# 물과 백두산이 마르고 닳도록
#
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# ### with 문
#
# * 항상 파일을 `open()` 함수로 열고, `close()` 함수로 닫아야 하는 일을 자동으로 처리
# * with문을 이용하면 with 블록 내에서 파일을 열고 벗어나면 파일을 닫음

# %%
f= open('file.txt','w')
f.write('hello world')
f.close()

# %%
with open('file.txt','w') as f:
  f.write('hello world')

# %% [markdown]
# ### [Lab] 표준 입력으로 받은 내용을 파일로 쓰기
#
# * 사용자로부터 표준 입력 받음
# * 받은 내용을 계속 파일 쓰기

# %%
f= open('file.txt','w')
line = ""
while True:
  line = input()
  if not line: break
  f.writelines(line + '\n')

f.close()
# Out:
# 1
# 12
# 123

# %%
# !cat file.txt
# Out:
# 1
# 12
# 123

# %% [markdown]
# * 이진 파일(이미지) 예제

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8d942ea3-ff6b-41a4-90ab-c0b15e6a6345" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d942ea3-ff6b-41a4-90ab-c0b15e6a6345">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving KakaoTalk_20200413_153217771.jpg to KakaoTalk_20200413_153217771.jpg
# {'KakaoTalk_20200413_153217771.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00CC"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x01\x00\x02\x03\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x08\t\x06\x07\n\x05\x04\x03\x02\x01\x0b\xff\xc4\x00w\x10\x00\x00\x06\x02\x01\x01\x04\x03\x04\x0f\x10\x0c\t\t\x01\x11\x01\x02\x03\x04\x05\x06\x00\x07\x08\x11\t\x12\x13\x14\x15\x16!\x171Q\xb3\x18\x19"45AWYu\x92\x93\x94\xd3\xd6\xd7\n#289SXaqtvw\x96\xb6\xb7\xd4$%367s\x81\x97\xa7\xb2\xb5\xd8\x1aBx\x91\xa1\xb1\xb4\xb8\xd2&\'RTr\x98\xa8\xc1\xf0:bi\xd1(EUVc\x88\x95\xe8\xf1)CD\x84\xa2\xff\xc4\x00\x1d\x01\x01\x01\x01\x01\x01\x00\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\xff\xc4\x00B\x11\x00\x01\x02\x03\x05\x05\x05\x06\x05\x03\x04\x02\x03\x01\x01\x01\x01\x00\x11\x02\x03!\x04\x051Aa\x06\x12Qq\x91\x81\xa1\xb1\xd1\xf0\x07\x13"2R\xc1Br\xa2\xd2\xe1\x14\x92\xf1\x15b\x82\xb2\x08#\x163\xc2$%\x17\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xb8\xde\xc3\x0e\xc2\xbe:\xf0\xa7\x8f\xba\xdbf\xec\x9dkY\xbar\xc6\xe9S\xae\xdb6\x05\xfe\xdf\x05\x1b?+@\x9b\x9c\x8ci,\xb5\x13_\x8c\xb3GD\xab\xb5\xad\x11\xd2q\xb2rq\xc9\xb7\x93\x9a\x91n\xbb\x85\x9c\x91\xb7\x84\xd9\x1e\x8d\x82\x87\x0cP\x00\x05_\x80\x00\x00\x00\x02\xc8\x00\x00\x00t\x00\x00\xf2\xbe\xc0\x0f\xa4\x1fH=\x98\xa1\x80\x16\x19P\x00\x00\x00~\xb0\x00\x00\x00\x00\x007k\xd0\x00\x03\xde\x00\xfaA\xef\x07\xd2\xcc\xd7-A58\xb3\x07\x02\x9d\xb8\x9c\xfc\x82\xe9\x14F\x13\xbb\x0f\xc2!\xa5\t\x04\x9a\x02I\xc4\xb9\x0f\xa6\x01\x85\x16\x17\xea$7\xeb\xd2\x1fvC\xfa\xae=D\x86\xfdzC\xee\xc8\x7fU\xcc\xd3\x18s\xc4\xf5+;\xf1\xfdQ\x7fq\xf3X_\xa8\x90\xdf\xafH}\xd9\x0f\xea\xb8\xf5\x12\x1b\xf5\xe9\x0f\xbb!\xfdW3La\xcf\x13\xd4\xa6\xfc\x7fT_\xdc|\xd6\x17\xea$7\xeb\xd2\x1fvC\xfa\xae=D\x86\xfdzC\xee\xc8\x7fU\xcc\xd3\x18s\xc4\xf5)\xbf\x1f\xd5\x17\xf7\x1f5\x85\xfa\x89\r\xfa\xf4\x87\xdd\x90\xfe\xab\x8fQ!\xbf^\x90\xfb\xb2\x1f\xd5s4\xc6\x1c\xf1=Jo\xc7\xf5E\xfd\xc7\xcda~\xa2C~\xbd!\xf7d?\xaa\xe3\xd4Ho\xd7\xa4>\xec\x87\xf5\\\xcd1\x87<OR\x9b\xf1\xfdQ\x7fq\xf3X_\xa8\x90\xdf\xafH}\xd9\x0f\xea\xb8\xf5\x12\x1b\xf5\xe9\x0f\xbb!\xfdW3La\xcf\x13\xd4\xa6\xfc\x7fT_\xdc|\xd6\x17\xea$7\xeb\xd2\x1fvC\xfa\xae=D\x86\xfdzC\xee\xc8\x7fU\xcc\xd3\x18s\xc4\xf5)\xbf\x1f\xd5\x17\xf7\x1f5\x85\xfa\x89\r\xfa\xf4\x87\xdd\x90\xfe\xab\x8fQ!\xbf^\x90\xfb\xb2\x1f\xd5s4\xc6\x1c\xf1=Jo\xc7\xf5E\xfd\xc7\xcda~\xa2C~\xbd!\xf7d?\xaa\xe3\xd4Ho\xd7\xa4>\xec\x87\xf5\\\xcd1\x87<OR\x9b\xf1\xfdQ\x7fq\xf3X_\xa8\x90\xdf\xafH}\xd9\x0f\xea\xb8\xf5\x12\x1b\xf5\xe9\x0f\xbb!\xfdW3La\xcf\x13\xd4\xa6\xfc\x7fT_\xdc|\xd6\x17\xea$7\xeb\xd2\x1fvC\xfa\xae=D\x86\xfdzC\xee\xc8\x7fU\xcc\xd3\x18s\xc4\xf5)\xbf\x1f\xd5\x17\xf7\x1f5\x85\xfa\x89\r\xfa\xf4\x87\xdd\x90\xfe\xab\x8fQ!\xbf^\x90\xfb\xb2\x1f\xd5s4\xc6\x1c\xf1=Jo\xc7\xf5E\xfd\xc7\xcda~\xa2C~\xbd!\xf7d?\xaa\xe3\xd4Ho\xd7\xa4>\xec\x87\xf5\\\xcd1\x87<OR\x9b\xf1\xfdQ\x7fq\xf3X_\xa8\x90\xdf\xafH}\xd9\x0f\xea\xb8\xf5\x12\x1b\xf5\xe9\x0f\xbb!\xfdW3La\xcf\x13\xd4\xa6\xfc\x7fT_\xdc|\xd6\x17\xea$7\xeb\xd2\x1fvC\xfa\xae=D\x86\xfdzC\xee\xc8\x7fU\xcc\xd3\x18s\xc4\xf5)\xbf\x1f\xd5\x17\xf7\x1f5\x85\xfa\x89\r\xfa\xf4\x87\xdd\x90\xfe\xab\x8fQ!\xbf^\x90\xfb\xb2\x1f\xd5s4\xc6\x1c\xf1=Jo\xc7\xf5E\xfd\xc7\xcda~\xa2C~\xbd!\xf7d?\xaa\xe3\xd4Ho\xd7\xa4>\xec\x87\xf5\\\xcd1\x87<OR\x9b\xf1\xfdQ\x7fq\xf3X_\xa8\x90\xdf\xafH}\xd9\x0f\xea\xb8\xf5\x12\x1b\xf5\xe9\x0f\xbb!\xfdW3La\xcf\x13\xd4\xa6\xfc\x7fT_\xdc|\xd6\x17\xea$7\xeb\xd2\x1fvC\xf ...

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  KakaoTalk_20200413_153217771.jpg  sample_data

# %% [markdown]
# ### 이진 파일 복사
#
# * 하나의 이진 파일을 읽어서 다른 이진 파일로 쓰기 (복사)

# %%
input = open('KakaoTalk_20200413_153217771.jpg','rb')
output = open('unname.jpg','wb')
while True:
  fp = input.read(1)
  if not fp: break
  output.write(fp)

input.close()
output.close()

# %%
# !ls
# Out:
# anthem.txt  file.txt			      sample_data
# dan.txt     KakaoTalk_20200413_153217771.jpg  unname.jpg

# %% [markdown]
# ## 디렉토리 및 파일 처리

# %% [markdown]
# ### 디렉토리 생성
#
# * 디렉토리와 파일을 다루는 다양한 함수를 제공하는 shutil와 os 라이브러리
# * `mkdir()`: 디렉토리 생성

# %%
import os
import shutil
os.mkdir('test')
os.mkdir('test/한글')
os.mkdir('test/2')
os.mkdir('test/3')

# %%
# !ls
# Out:
# anthem.txt  file.txt			      sample_data  text
# dan.txt     KakaoTalk_20200413_153217771.jpg  test	   unname.jpg

# %%
# !ls test
# Out:
# 한글  2  3

# %% [markdown]
# ### 디렉토리 및 파일 복사
#
# * `shutil.copy()`: 파일 복사
# * `shutil.copytree()`: 디렉토리 전체 복사

# %%
import shutil
shutil.copy('unname.jpg','unname_1.jpg')
# Out:
# 'unname_1.jpg'

# %%
# !ls
# Out:
# anthem.txt  KakaoTalk_20200413_153217771.jpg  text
# dan.txt     sample_data			      unname_1.jpg
# file.txt    test			      unname.jpg

# %%
import shutil
shutil.copytree('test','test2')
# Out:
# 'test2'

# %%
# !ls
# Out:
# anthem.txt  file.txt			      sample_data  test2  unname_1.jpg
# dan.txt     KakaoTalk_20200413_153217771.jpg  test	   text   unname.jpg

# %%
# !ls test2
# Out:
# 한글  2  3

# %% [markdown]
# ### 디렉토리 및 파일 확인
#
# * `isdir()`: 디렉토리 존재 확인
# * `isfile()`: 파일 존재 확인
# * `exists()`: 디렉토리/파일 존재 확인

# %%
import os.path
print(os.path.isdir('test'))
print(os.path.isdir('test/1'))
print(os.path.isdir('test/2'))
print(os.path.isfile('unnane.jpg'))
print(os.path.exists('test/3'))
print(os.path.isdir('test2/2'))
print(os.path.isdir('test2/1'))
# Out:
# True
# False
# True
# False
# True
# True
# False

# %% [markdown]
# ### 디렉토리 목록 보기
#
# * `os.walk()`: 디렉토리 목록 보기

# %%
import os
for dir_name, dir_list,file_names in os.walk('./'): #,/현재디렉토레이 대해서만 위치값 제공
  for file_name in file_names:
    print(os.path.join(dir_name, file_name))
# Out:
# ./unname.jpg
# ./unname_1.jpg
# ./anthem.txt
# ./KakaoTalk_20200413_153217771.jpg
# ./file.txt
# ./dan.txt
# ./.config/.last_survey_prompt.yaml
# ./.config/active_config
# ./.config/config_sentinel
# ./.config/gce
# ./.config/.last_update_check.json
# ./.config/.last_opt_in_prompt.yaml
# ./.config/.metricsUUID
# ./.config/configurations/config_default
# ./.config/logs/2020.06.26/16.25.58.989664.log
# ./.config/logs/2020.06.26/16.25.38.639070.log
# ./.config/logs/2020.06.26/16.26.32.322745.log
# ./.config/logs/2020.06.26/16.26.18.185568.log
# ./.config/logs/2020.06.26/16.26.12.354762.log
# ./.config/logs/2020.06.26/16.26.31.787344.log
# ./sample_data/README.md
# ./sample_data/anscombe.json
# ./sample_data/california_housing_train.csv
# ./sample_data/mnist_test.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_test.csv

# %% [markdown]
# ### 디렉토리 및 파일 삭제
#
# * `os.remove()`: 파일 삭제
# * `shutil.rmtree()`: 디렉토리 안에 모든 파일/디렉토리 삭제

# %%
import os
os.remove('unname_1.jpg')
os.remove('unname.jpg')

# %%
# !ls
# Out:
# anthem.txt  file.txt			      sample_data  test2
# dan.txt     KakaoTalk_20200413_153217771.jpg  test	   text

# %%
import shutil
shutil.rmtree('text')
shutil.rmtree('test2')

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  KakaoTalk_20200413_153217771.jpg  sample_data

# %% [markdown]
# ### 파일 크기
#
# * `os.path.getsize()`: 파일의 크기를 바이트 단위로 출력

# %%
import os.path
print(os.path.getsize('KakaoTalk_20200413_153217771.jpg'))
# Out:
# 200871

# %% [markdown]
# ### 파일 압축

# %%
import zipfile
comp = zipfile.ZipFile('new.zip','w')
comp.write('KakaoTalk_20200413_153217771.jpg')
comp.close()

# %%
# !ls
# Out:
# anthem.txt  file.txt			      new.zip
# dan.txt     KakaoTalk_20200413_153217771.jpg  sample_data

# %%
decomp = zipfile.ZipFile('new.zip','r')
decomp.extractall('new')
decomp.close()

# %%
# !ls new
# Out:
# KakaoTalk_20200413_153217771.jpg
