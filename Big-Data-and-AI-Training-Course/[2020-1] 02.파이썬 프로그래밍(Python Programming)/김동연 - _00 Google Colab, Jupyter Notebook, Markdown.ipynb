# %% [markdown]
# # Google Colaboratory

# %% [markdown]
# ---

# %% [markdown]
# ## Google Colab 사양

# %% [markdown]
# * 플랫폼

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %% [markdown]
# * 운영체제

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.3 LTS

# %% [markdown]
# * CPU 사양

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: AuthenticAMD
# cpu family	: 23
# model		: 49
# model name	: AMD EPYC 7B12
# stepping	: 0
# microcode	: 0x1000065
# cpu MHz		: 2249.998
# cache size	: 512 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid extd_apicid tsc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext ssbd ibrs ibpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_save umip rdpid
# bugs		: sysret_ss_attrs spectre_v1 spectre_v2 spec_store_bypass
# bogomips	: 4499.99
# TLB size	: 3072 4K pages
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 48 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: AuthenticAMD
# cpu family	: 23
# model		: 49
# model name	: AMD EPYC 7B12
# stepping	: 0
# microcode	: 0x1000065
# cpu MHz		: 2249.998
# cache size	: 512 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid extd_apicid tsc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext ssbd ibrs ibpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_save umip rdpid
# bugs		: sysret_ss_attrs spectre_v1 spectre_v2 spec_store_bypass
# bogomips	: 4499.99
# TLB size	: 3072 4K pages
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 48 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# * 메모리 사양

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13333540 kB
# MemFree:        10532732 kB
# MemAvailable:   12453432 kB
# Buffers:           72688 kB
# Cached:          2006320 kB
# SwapCached:            0 kB
# Active:           728980 kB
# Inactive:        1782944 kB
# Active(anon):     412996 kB
# Inactive(anon):      332 kB
# Active(file):     315984 kB
# Inactive(file):  1782612 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              1900 kB
# Writeback:             0 kB
# AnonPages:        432956 kB
# Mapped:           225900 kB
# Shmem:               944 kB
# Slab:             164792 kB
# SReclaimable:     126176 kB
# SUnreclaim:        38616 kB
# KernelStack:        3604 kB
# PageTables:         5512 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6666768 kB
# Committed_AS:    2478116 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# VmallocChunk:          0 kB
# Percpu:              920 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      103612 kB
# DirectMap2M:     5138432 kB
# DirectMap1G:    10485760 kB

# %% [markdown]
# * 디스크 사양

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   32G   72G  31% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# shm             5.9G     0  5.9G   0% /dev/shm
# tmpfs           6.4G   12K  6.4G   1% /var/colab
# /dev/sda1       114G   33G   82G  29% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %% [markdown]
# * 파이썬 버전

# %%
# !python --version
# Out:
# Python 3.6.9

# %% [markdown]
# ## Google Colab 런타임
# * Colab에서 고성능 하드웨어로 GPU나 TPU 사용 가능
# * 런타임 유형 변경(Change runtime type) 필요
#   + None: CPU만 사용
#   + GPU: 하드웨어 가속으로 GPU 사용
#   + TPU: 하드웨어 가속으로 TPU 사용

# %%
# !nvidia-smi
# Out:
# Mon Jun 29 10:52:38 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P8    33W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 파일 저장 및 다운로드/업로드
#
# * Jupyter Notebook 환경에서 파일 저장 및 다운로드

# %%
# %%writefile test.txt
# text
# Out:
# Writing test.txt

# %%
# !cat test.txt
# Out:
# text

# %%
from google.colab import files
files.download('test.txt')

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-80855d72-f503-4bd0-a20b-7bc5c37f7537" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80855d72-f503-4bd0-a20b-7bc5c37f7537">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving KCase.log to KCase.log

# %%
# !ls
# Out:
# KCase.log  sample_data	test.txt

# %% [markdown]
# ## Google Drive 연동
#
# * Google Colab은 Google Drive와 `mount`를 통해 쉽게 연동 가능
# * Google Drive에 소스 코드 저장 뿐만 아니라 파일을 열거나 저장 가능

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls /content/drive
# Out:
# 'My Drive'

# %% [markdown]
# ---

# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# ## help()
#
# * 파이썬 객체에 대한 요약 정보와 사용법 보기

# %%
help(min)
# Out:
# Help on built-in function min in module builtins:
#
# min(...)
#     min(iterable, *[, default=obj, key=func]) -> value
#     min(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its smallest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the smallest argument.

# %% [markdown]
# ## ?로 설명 보기
#
# * 객체 요약 정보 및 사용법이 있는 docstring 보기

# %%
max?

# %%
li = ["one",'two','three']
li?

# %%
li.count?

# %%
def power(b,n):
  """b의 n승을 반환"""
  return pow(b,m)

# %%
power?

# %%
power??

# %% [markdown]
# ## 탭(tab) 자동완성
#
# * 객체와 모듈, 인터페이스의 내용을 자동 완성

# %%
li = ['one','two','three']
li.append
li.clear
li.count
# Out:
# <function list.count>

# %% [markdown]
# ##와일드카드(wildcard) 매칭
#
# * 단어의 중간이나 마지막 글자로 매칭하여 객체나 속성 찾기

# %%
*Error?

# %%
str.*index*?

# %% [markdown]
# ## 매직 명령어(magic commands)
#
# * Jupyter Notebook 환경에서 파이썬 파일 저장 및 실행

# %%
# %%writefile test.py
print('hello cola')
# Out:
# Writing test.py

# %%
# %run test.py
# Out:
# hello cola

# %% [markdown]
# * 코드 실행 시간 측정

# %%
# %%timeit?

# %%
# %timeit li = [n ** n for n in range(10000)]
# Out:
# 1 loop, best of 3: 5.75 s per loop

# %%
# %%timeit 
li = []
for n in range(10000):
  li.append(n ** n)
# Out:
# 1 loop, best of 3: 5.76 s per loop

# %% [markdown]
# ## 입력과 출력 이력
#
# * In과 Out 객체를 통해 이전 명령어와 명령어의 출력 결과 보기

# %%
In
# Out:
# ['',
#  "get_ipython().system('cat /proc/meminfo')",
#  "get_ipython().system('nvidia-smi')",
#  "get_ipython().run_cell_magic('writefile', 'test.txt', '')",
#  "get_ipython().run_cell_magic('writefile', 'test.txt', 'text')",
#  "get_ipython().system('cat test.txt')",
#  "from google.colab import files\nfiles.download('test/txt')",
#  "from google.colab import files\nfiles.download('test.txt')",
#  'upload = files.upload()',
#  "get_ipython().system('ls')",
#  "from google.colab import drive\ndrive.mount('/content/drive')",
#  "get_ipython().system('ls /content/drive')",
#  'help(min)',
#  "get_ipython().magic('pinfo max')",
#  'li = ["one",\'two\',\'three\']',
#  'li = ["one",\'two\',\'three\']\nget_ipython().magic(\'pinfo lo\')',
#  'li = ["one",\'two\',\'three\']\nget_ipython().magic(\'pinfo li\')',
#  "get_ipython().magic('pinfo li.count')",
#  'def power(b,n):\n  """b의 n승을 반환"""\n  return pow(b,m)',
#  "get_ipython().magic('pinfo power')",
#  "get_ipython().magic('pinfo2 power')",
#  "li = ['one','two','three']\nget_ipython().magic('pinfo li')",
#  "li = ['one','two','three']\nli.append\nli.clear\nli.count",
#  "get_ipython().magic('psearch *Error')",
#  "get_ipython().magic('psearch str.*index*')",
#  'get_ipython().run_cell_magic(\'writefile\', \'test.py\', "print(\'hello cola\')")',
#  "get_ipython().magic('run test.py')",
#  "get_ipython().magic('pinfo %%timeit')",
#  "get_ipython().magic('timeit li = [n ** n for n in range(1000)]')",
#  "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n li.append( n**n)')",
#  "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n li.append(n ** n)')",
#  "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n  li.append(n ** n)')",
#  "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n  li.append(n ** n)')",
#  "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000):\\n  li.append(n ** n)')",
#  "get_ipython().magic('timeit li = [n ** n for n in range(10000)]')",
#  "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000):\\n  li.append(n ** n)')",
#  'ㅑㅜ',
#  'in',
#  'In']

# %%
In[26]
# Out:
# "get_ipython().magic('run test.py')"

# %%
Out
# Out:
# {22: <function list.count>,
#  38: ['',
#   "get_ipython().system('cat /proc/meminfo')",
#   "get_ipython().system('nvidia-smi')",
#   "get_ipython().run_cell_magic('writefile', 'test.txt', '')",
#   "get_ipython().run_cell_magic('writefile', 'test.txt', 'text')",
#   "get_ipython().system('cat test.txt')",
#   "from google.colab import files\nfiles.download('test/txt')",
#   "from google.colab import files\nfiles.download('test.txt')",
#   'upload = files.upload()',
#   "get_ipython().system('ls')",
#   "from google.colab import drive\ndrive.mount('/content/drive')",
#   "get_ipython().system('ls /content/drive')",
#   'help(min)',
#   "get_ipython().magic('pinfo max')",
#   'li = ["one",\'two\',\'three\']',
#   'li = ["one",\'two\',\'three\']\nget_ipython().magic(\'pinfo lo\')',
#   'li = ["one",\'two\',\'three\']\nget_ipython().magic(\'pinfo li\')',
#   "get_ipython().magic('pinfo li.count')",
#   'def power(b,n):\n  """b의 n승을 반환"""\n  return pow(b,m)',
#   "get_ipython().magic('pinfo power')",
#   "get_ipython().magic('pinfo2 power')",
#   "li = ['one','two','three']\nget_ipython().magic('pinfo li')",
#   "li = ['one','two','three']\nli.append\nli.clear\nli.count",
#   "get_ipython().magic('psearch *Error')",
#   "get_ipython().magic('psearch str.*index*')",
#   'get_ipython().run_cell_magic(\'writefile\', \'test.py\', "print(\'hello cola\')")',
#   "get_ipython().magic('run test.py')",
#   "get_ipython().magic('pinfo %%timeit')",
#   "get_ipython().magic('timeit li = [n ** n for n in range(1000)]')",
#   "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n li.append( n**n)')",
#   "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n li.append(n ** n)')",
#   "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n  li.append(n ** n)')",
#   "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n  li.append(n ** n)')",
#   "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000):\\n  li.append(n ** n)')",
#   "get_ipython().magic('timeit li = [n ** n for n in range(10000)]')",
#   "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000):\\n  li.append(n ** n)')",
#   'ㅑㅜ',
#   'in',
#   'In',
#   'In[62]',
#   'In[26]',
#   'Out[2]',
#   'Out[31]',
#   'Out'],
#  40: "get_ipython().magic('run test.py')"}

# %%
Out[40]
# Out:
# "get_ipython().magic('run test.py')"

# %%
print("In[31]: " + In[31] + "\nOut[40]: " + Out[40])
# Out:
# In[31]: get_ipython().run_cell_magic('timeit', '', 'li = []\nfor n in range(10000)\n  li.append(n ** n)')
# Out[40]: get_ipython().magic('run test.py')

# %% [markdown]
# * `_`를 이용해 이전 출력값 출력하기

# %%
print(_)
# Out:
# get_ipython().magic('run test.py')

# %%
print(__)
# Out:
# get_ipython().magic('run test.py')

# %%
print(___)
# Out:
# ['', "get_ipython().system('cat /proc/meminfo')", "get_ipython().system('nvidia-smi')", "get_ipython().run_cell_magic('writefile', 'test.txt', '')", "get_ipython().run_cell_magic('writefile', 'test.txt', 'text')", "get_ipython().system('cat test.txt')", "from google.colab import files\nfiles.download('test/txt')", "from google.colab import files\nfiles.download('test.txt')", 'upload = files.upload()', "get_ipython().system('ls')", "from google.colab import drive\ndrive.mount('/content/drive')", "get_ipython().system('ls /content/drive')", 'help(min)', "get_ipython().magic('pinfo max')", 'li = ["one",\'two\',\'three\']', 'li = ["one",\'two\',\'three\']\nget_ipython().magic(\'pinfo lo\')', 'li = ["one",\'two\',\'three\']\nget_ipython().magic(\'pinfo li\')', "get_ipython().magic('pinfo li.count')", 'def power(b,n):\n  """b의 n승을 반환"""\n  return pow(b,m)', "get_ipython().magic('pinfo power')", "get_ipython().magic('pinfo2 power')", "li = ['one','two','three']\nget_ipython().magic('pinfo li')", "li = ['one','two','three']\nli.append\nli.clear\nli.count", "get_ipython().magic('psearch *Error')", "get_ipython().magic('psearch str.*index*')", 'get_ipython().run_cell_magic(\'writefile\', \'test.py\', "print(\'hello cola\')")', "get_ipython().magic('run test.py')", "get_ipython().magic('pinfo %%timeit')", "get_ipython().magic('timeit li = [n ** n for n in range(1000)]')", "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n li.append( n**n)')", "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n li.append(n ** n)')", "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n  li.append(n ** n)')", "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000)\\n  li.append(n ** n)')", "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000):\\n  li.append(n ** n)')", "get_ipython().magic('timeit li = [n ** n for n in range(10000)]')", "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000):\\n  li.append(n ** n)')", 'ㅑㅜ', 'in', 'In', 'In[62]', 'In[26]', 'Out[2]', 'Out[31]', 'Out', 'Oun[40]', 'Oun[38]', 'Out[40]', 'print("In[31:" + In[31] + "\\nOut[40]" + Out[40])', 'print("In[31: " + In[31] + "\\nOut[40] " + Out[40])', 'print("In[31]: " + In[31] + "\\nOut[40] " + Out[40])', 'print("In[31]: " + In[31] + "\\nOut[40] :" + Out[40])', 'print("In[31]: " + In[31] + "\\nOut[40]: " + Out[40])', 'print(_)', 'print(__)', 'print(___)']

# %%
_40
# Out:
# "get_ipython().magic('run test.py')"

# %% [markdown]
# * `%history`를 이용한 입력 이력 살펴보기

# %%
# %history -n 1-7
# Out:
#    1: !cat /proc/meminfo
#    2: !nvidia-smi
#    3: %%writefile test.txt
#    4:
# %%writefile test.txt
# text
#    5: !cat test.txt
#    6:
# from google.colab import files
# files.download('test/txt')
#    7:
# from google.colab import files
# files.download('test.txt')

# %% [markdown]
# * `%rerun`을 이용해 이전 입력 이력 다시 실행

# %%
# %rerun
# Out:
# === Executing: ===
# %history -n 1-7
# === Output: ===
#    1: !cat /proc/meminfo
#    2: !nvidia-smi
#    3: %%writefile test.txt
#    4:
# %%writefile test.txt
# text
#    5: !cat test.txt
#    6:
# from google.colab import files
# files.download('test/txt')
#    7:
# from google.colab import files
# files.download('test.txt')

# %% [markdown]
# ## 셸 명령어
#
# * 텍스트 기반의 셸 명령어 처리
# * `!` 문자를 명령어 앞에 붙여서 셸 명령어 사용 가능

# %% [markdown]
# * `ls`: 디렉토리 리스트 보기

# %%
# !ls
# Out:
# drive  KCase.log  sample_data  test.py	test.txt

# %% [markdown]
# * `pwd`: 현재 경로 보기

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# * `cd`: 디렉토리 변경
# * IPython에서는 임시 셸에서 실행

# %%
# !cd KCase.log/ $$ ls
# Out:
# /bin/bash: line 0: cd: too many arguments

# %% [markdown]
# * `%cd`: 지속적인 디렉토리 변경

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %% [markdown]
# * `echo`: 화면 출력

# %%
# !echo "shell"
# Out:
# shell

# %% [markdown]
# * `mkdir`: 디렉토리 생성

# %%
# !mkdir tmp

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv	     tmp
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %% [markdown]
# * `cat`: 파일 보기

# %%
# !cat README.md
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %% [markdown]
# * `cp`: 디렉토리/파일 복사

# %%
# !cp README.md tmp/

# %%
# !ls tmp/
# Out:
# README.md

# %% [markdown]
# * `rm`: 디렉토리/파일 삭제

# %%
# !rm -r tmp

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %% [markdown]
# ---

# %% [markdown]
# # 마크다운(Markdown)
# ## Heading1
# ### Heading2
# * 문법이 간단하고, 사용이 쉬움

# %% [markdown]
# ## 제목(Heading) 표시

# %% [markdown]
# ## Heading1
# ### Heading2

# %% [markdown]
# ## 목록(List) 구성

# %% [markdown]
# 1. 첫째
# 2. 둘째
# 3. 셋째
# * 1단계
#   + 2단계
#     - *3단계*

# %% [markdown]
# ## 폰트 스타일(Font Style)

# %% [markdown]
# **bold**
# __bold__
# *itolic*

# %% [markdown]
# ## 인용구

# %% [markdown]
# > 인용1
# >> 인 용2
# >>>인용3

# %% [markdown]
# ## 링크

# %% [markdown]
# [google](https://www.google.com)

# %% [markdown]
# ## 이미지

# %% [markdown]
# ![이미지](https://www.google.com/images/branding.googlelogo/1x/googlelogo_color_272x92dp.png)

# %% [markdown]
# ## 수평선

# %% [markdown]
# ---

# %% [markdown]
# ## 표

# %% [markdown]
# | C1 | C2 | C3  |
# |:---|---:|:---:|
# | D1 | D2 | D3 |

# %% [markdown]
# ## 코드

# %% [markdown]
# `inline cod`
#
# ```phthon
# def power(b,n)
#  return pow(b,n)
# ```

# %%
# Out:
# 'phyton\ndef power(b,n)\n return pow(b,n)\n'
