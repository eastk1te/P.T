# %% [markdown]
# - 내용 및 코드 참조
#
#   - 케라스 창시자로부터 배우는 딥러닝
#
#   - 미술관에 GAN 딥러닝 실전 프로젝트

# %% [markdown]
# # 적대적 생성 신경망(Generative Adversarial Networks, GAN)
#
# - 2014년, Ian Goodfellow 소개
#
# - VAE와는 다른 방법으로 이미지 잠재 공간을 학습
#
# - 직관적으로 이해하는 방법
#
#   - 가짜 피카소 그림을 그리는 위조범과 이를 판별하는 판매상의 관계
#
#   - 위조품과 진짜 그림을 섞어서 판매상에게 보여주며
#     그림이 진짜인지 가짜인지 판매상은 판별하고 이를 위조범에게 피드백
#
#   - 처음에는 형편없는 그림을 그리다가 점점 피카소의 스타일을 모방하게 되고
#     판매상은 위조품을 구분하는데 점점 더 전문가가 되어감
#
# - GAN의 네트워크
#
#   - 생성자 네트워크(generator network)
#
#     - 랜덤 벡터(잠재 공간의 무작위한 포인트)를 입력으로 받아 이를 합성된 이미지로 디코딩
#
#   - 판별자 네트워크(discriminator netowrk)
#
#     - 이미지(실제 또는 가짜 이미지)를 입력으로 받아 훈련 세트에서 온 이미지인지 생성자가 만든 이미지인지 판별
#
# - GAN은 최적화의 최솟값이 고정되어 있지 않음
#
#   - 보통의 경사하강법은 **고정된 손실공간**에서 언덕을 내려오는 훈련 방법이지만
#     GAN은 매 단계가 조금씩 전체 공간을 바꾸기 때문에 최적화 과정이 최솟값을 찾는 것이 어려움
#
#   - 두 힘간의 평형점을 찾는 시스템
#
#   - 따라서, 학습과정이 매우 어려움
#     즉, 적절한 파라미터를 찾고 조정해야함
#
#   <img src="https://paperswithcode.com/media/methods/gan.jpeg">
#
#   <sub>[이미지 출처] https://paperswithcode.com/method/gan</sub>

# %% [markdown]
# ## GAN의 구현 (DCGAN)
#
# - CIFAR10 데이터셋 사용
#
# - generator 네트워크는 (latent_dim,) 크기의 벡터를 (32, 32, 3) 크기의 이미지로 매핑
#
# - discriminator 네트워크는 (32, 32, 3) 크기의 이미지가 진짜일 확률을 추정하여 이진값으로 매핑
#
# - 생성자와 판별자를 연결하는 gan 네트워크를 만듬
#
#   - gan(x) = discriminator(generator(x))
#
# - 진짜/가짜 레이블과 함께 진짜 이미지와 가짜 이미지 샘플을 사용하여 판별자를 훈련 (일반적인 이미지 분류 모델 훈련과 동일)
#
# - 생성자를 훈련하려면 gan 모델의 손실에 대한 생성자 가중치의 그래디언트를 사용
#
#   - 매 단계마다 생성자에 의해 디코딩된 이미지를 판별자가 "진짜"로 분류하도록 만다는 방향으로 생성자의 가중치를 이동
#
#   - 판별자를 속이도록 생성자를 훈련한다는 말

# %% [markdown]
# ## 학습 방법
#
# - 마지막 활성화 함수로 sigmoid 대신 tanh함수 사용
#
# - 균등분포가 아니고 정규 분포(가우시안 분포)를 사용하여 잠재 공간에서 포인트를 샘플링
#
# - 무작위성을 주입
#
#   - 판별자에 드롭아웃을 사용
#
#   - 판별자를 위해 레이블에 랜덤 노이즈를 추가
#
# - 희소한 그래디언트는 GAN 훈련에 방해가 될 수 있음
#
#   - 최대 풀링 대신 스트라이드 합성곱을 사용하여 다운샘플링
#
#   - ReLU 대신 LeakyReLU 사용
#
# - 생성자에서 픽셀 공간을 균일하게 다루지 못하여 생성된 이미지에서 체스판 모양이 종종 나타남.
#   이를 위해 생성자와 판별자에서 스트라이드 Conv2DTranpose나 Conv2D를 사용할 때 스트라이드 크기로 나누어 질 수 있는 커널 크기 사용
#
#   - 커널 크기가 스트라이드의 배수가 아니면 픽셀이 공평하게 합성곱 되지 않음
#     커널 크기를 스트라이드로 나누었을 때 나머지 크기에 해당하는 픽셀이 더 많이 업샘플링에 참여하게 됨

# %% [markdown]
# ### GAN 생성자 네트워크

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Reshape,Conv2D,Conv2DTranspose,Flatten,Dropout
from tensorflow.keras.models import Model
import numpy as np

# %%
latent_dim = 32
height = 32
width = 32
channels = 3

# %%
generator_input = Input(shape=(latent_dim,))

# %%
x = Dense(128 * 16 * 16)(generator_input)
x = LeakyReLU()(x)
x = Reshape((16,16,128))(x)

x = Conv2D(256,5,padding='same')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(256,4,strides=2,padding='same')(x)
x = LeakyReLU()(x)

x = Conv2D(256,5,padding='same')(x)
x = LeakyReLU()(x)
x = Conv2D(256,5,padding='same')(x)
x = LeakyReLU()(x)

x = Conv2D(channels, 7, activation='tanh',padding='same')(x)

# %%
generator = Model(generator_input, x)
generator.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### GAN 판별자 네트워크

# %%
discriminator_input = Input(shape=(height, width, channels))

# %%
x = Conv2D(128,3)(discriminator_input)
x = LeakyReLU()(x)
x = Conv2D(128,4,strides=2)(x)
x = LeakyReLU()(x)
x = Conv2D(128,4,strides=2)(x)
x = LeakyReLU()(x)
x = Conv2D(128,4,strides=2)(x)
x = LeakyReLU()(x)
x = Flatten()(x)
x = Dropout(0.4)(x)
x = Dense(1, activation='sigmoid')(x)

# %%
discriminator = Model(discriminator_input,x)
discriminator.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
discriminator_optimizer = RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')

# %% [markdown]
# ### 적대적 네트워크
# - 생성자와 판별자를 연결
#
# - 훈련할 때 생성자가 판별자를 속이는 능력이 커지도록 학습
#
# - 잠재 공간의 포인트를 진짜 또는 가짜의 분류 결정으로 변환
#
# - 훈련에 사용되는 target label은 항상 "진짜 이미지"
#
# - 훈련하는 동안 판별자를 동결(학습되지 않도록)하는 것이 매우 중요!
#
#   - 판별자의 가중치가 훈련하는 동안 업데이트되면 판별자는 항상 진짜를 예측하도록 훈련됨

# %%
discriminator.trainable = False
gan_input = Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan  = Model(gan_input, gan_output)

gan_optimizer = RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %% [markdown]
# ### GAN 훈련 구현
#
# - DCGAN 구현
#
# - 매 반복마다 아래의 과정 수행
#
#   1. 잠재 공간에서 무작위로 포인트를 뽑음(랜덤 노이즈)
#
#   2. 랜덤 노이즈를 사용하여 generator에서 이미지를 생성
#
#   3. 생성된 이미지와 진짜 이미지를 섞음
#
#   4. 진짜와 가짜가 섞인 이미지와 이에 대응하는 타깃을 사용하여 discriminator를 훈련
#     타킷은 진짜 또는 가짜
#
#   5. 잠재 공간에서 무작위로 새로운 포인트를 뽑음
#
#   6. 랜덤 벡터를 사용하여 gan을 훈련.
#     모든 타깃은 진짜로 설정.
#     - 판별자가 생성된 이미지를 모두 "진짜 이미지"라고 예측하도록 생성자의 가중치를 업데이트.
#       (판별자는 동결되기 때문에 생성자만 업데이트)

# %%
import os
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing import image

# %% [markdown]
# #### CIFAR10 데이터 로드

# %%
(x_train, y_train),(_,_) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step

# %% [markdown]
# #### 개구리 이미지를 선택

# %%
x_train = x_train[y_train.flatten() == 6]

# %% [markdown]
# #### 데이터 정규화

# %%
x_train = x_train. reshape((x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

# %%
iterations = 10000
batch_size = 20

save_dir = '/content/gan_images/'
if not os.path.exists(save_dir):
  os.mkdir(save_dir)

# %% [markdown]
# #### 학습

# %%
start = 0
for step in range(iterations):
  random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
  generated_images = generator.predict(random_latent_vectors)

  stop = start + batch_size
  real_images = x_train[start:stop]
  combined_images = np.concatenate([generated_images, real_images])
  labels = np.concatenate([np.ones((batch_size, 1)),
                           np.zeros((batch_size, 1))])
  labels += 0.05 * np.random.random(labels.shape)

  d_loss = discriminator.train_on_batch(combined_images, labels)

  random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
  misleading_targets = np.zeros((batch_size,1))

  a_loss = gan.train_on_batch(random_latent_vectors,misleading_targets)
  start += batch_size
  if start > len(x_train) - batch_size:
    start = 0

  if step % 100 == 0:
    gan.save_weights('gan.h5')

    print('\nstep: {}'.format(step))
    print(' discriminator loss: {}'.format(d_loss))
    print(' adversarial loss: {}'.format(a_loss))

    img = image.array_to_img(generated_images[0] * 255., scale= False)
    img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

    img = image.array_to_img(generated_images[0] * 255., scale= False)
    img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# step: 0
#  discriminator loss: 0.8525772094726562
#  adversarial loss: 7.797097682952881
#
# step: 100
#  discriminator loss: 0.6654521822929382
#  adversarial loss: 0.7987896203994751
#
# step: 200
#  discriminator loss: 0.597547173500061
#  adversarial loss: 1.1090211868286133
#
# step: 300
#  discriminator loss: 0.7401045560836792
#  adversarial loss: 0.7445929646492004
#
# step: 400
#  discriminator loss: 0.7050890922546387
#  adversarial loss: 0.7585117220878601
#
# step: 500
#  discriminator loss: 0.6895416975021362
#  adversarial loss: 0.6145231127738953
#
# step: 600
#  discriminator loss: 0.6855964660644531
#  adversarial loss: 0.8273302316665649
#
# step: 700
#  discriminator loss: 0.7006679177284241
#  adversarial loss: 0.7665270566940308
#
# step: 800
#  discriminator loss: 0.6956871747970581
#  adversarial loss: 0.7501426935195923
#
# step: 900
#  discriminator loss: 0.7709599733352661
#  adversarial loss: 0.7851191759109497
#
# step: 1000
#  discriminator loss: 0.700052797794342
#  adversarial loss: 0.7587099075317383
#
# step: 1100
#  discriminator loss: 0.6966320872306824
#  adversarial loss: 0.7504878640174866
#
# step: 1200
#  discriminator loss: 0.691153883934021
#  adversarial loss: 0.7328824996948242
#
# step: 1300
#  discriminator loss: 0.7011028528213501
#  adversarial loss: 0.7712124586105347
#
# step: 1400
#  discriminator loss: 0.6618109941482544
#  adversarial loss: 1.2233822345733643
#
# step: 1500
#  discriminator loss: 0.6890960335731506
#  adversarial loss: 0.7586394548416138
#
# step: 1600
#  discriminator loss: 0.7136354446411133
#  adversarial loss: 0.7578221559524536
#
# step: 1700
#  discriminator loss: 0.6855998039245605
#  adversarial loss: 0.7494007349014282
#
# step: 1800
#  discriminator loss: 0.7360986471176147
#  adversarial loss: 0.7690641283988953
#
# step: 1900
#  discriminator loss: 0.6873093247413635
#  adversarial loss: 0.7339350581169128
#
# step: 2000
#  discriminator loss: 0.6919528841972351
#  adversarial loss: 0.7374566793441772
#
# step: 2100
#  discriminator loss: 0.695102870464325
#  adversarial loss: 0.7851621508598328
#
# step: 2200
#  discriminator loss: 0.7100365161895752
#  adversarial loss: 0.75914466381073
#
# step: 2300
#  discriminator loss: 0.6785612106323242
#  adversarial loss: 0.848271369934082
#
# step: 2400
#  discriminator loss: 0.6964823007583618
#  adversarial loss: 0.8367401957511902
#
# step: 2500
#  discriminator loss: 0.682927131652832
#  adversarial loss: 0.7456928491592407
#
# step: 2600
#  discriminator loss: 0.6997265815734863
#  adversarial loss: 0.7779061198234558
#
# step: 2700
#  discriminator loss: 0.6829837560653687
#  adversarial loss: 0.7784370183944702
#
# step: 2800
#  discriminator loss: 0.6972519159317017
#  adversarial loss: 0.7736788392066956
#
# step: 2900
#  discriminator loss: 0.688386082649231
#  adversarial loss: 0.8869040608406067
#
# step: 3000
#  discriminator loss: 0.6868143081665039
#  adversarial loss: 0.7790491580963135
#
# step: 3100
#  discriminator loss: 0.7354551553726196
#  adversarial loss: 0.817703902721405
#
# step: 3200
#  discriminator loss: 0.6910662651062012
#  adversarial loss: 0.751787543296814
#
# step: 3300
#  discriminator loss: 0.6968380808830261
#  adversarial loss: 0.7903750538825989
#
# step: 3400
#  discriminator loss: 0.964128315448761
#  adversarial loss: 1.1985440254211426
#
# step: 3500
#  discriminator loss: 0.6974379420280457
#  adversarial loss: 0.8581045269966125
#
# step: 3600
#  discriminator loss: 0.6899582743644714
#  adversarial loss: 0.7848678231239319
#
# step: 3700
#  discriminator loss: 0.681636393070221
#  adversarial loss: 0.8424260020256042
#
# step: 3800
#  discriminator loss: 0.6909414529800415
#  adversarial loss: 0.7488768696784973
#
# step: 3900
#  discriminator loss: 0.6932146549224854
#  adversarial loss: 0.7596321702003479
#
# step: 4000
#  discriminator loss: 0.680578351020813
#  adversarial loss: 0.7571326494216919
#
# step: 4100
#  discriminator loss: 0.703356146812439
#  adversarial loss: 0.7765872478485107
#
# step: 4200
#  discriminator loss: 0.7694130539894104
#  adversarial loss: 0.7875741124153137
#
# step: 4300
#  discriminator loss: 0.6960415840148926
#  adversarial loss: 0.799232006072998
#
# step: 4400
#  discriminator loss: 0.6920949220657349
#  adversarial loss: 0.7293819189071655
#
# step: 4500
#  discriminator loss: 0.6708471179008484
#  adversarial loss: 1.3454965353012085
#
# step: 4600
#  discriminator loss: 0.6954103112220764
#  adversarial loss: 0.8120205998420715
#
# step: 4700
#  discriminator loss: 0.7045656442642212
#  adversarial loss: 0.8616301417350769
#
# step: 4800
#  discriminator loss: 0.6570776700973511
#  adversarial loss: 0.7466849088668823
#
# step: 4900
#  discriminator loss: 0.6812343597412109
#  adversarial loss: 0.8100481033325195
#
# step: 5000
#  discriminator loss: 0.6877222657203674
#  adversarial loss: 0.8902864456176758
#
# step: 5100
#  discriminator loss: 0.6959402561187744
#  adversarial loss: 0.7940313220024109
#
# step: 5200
#  discriminator loss: 0.6805865168571472
#  adversarial loss: 0.8114023208618164
#
# step: 5300
#  discriminator loss: 0.6572704315185547
#  adversarial loss: 0.8423247337341309
#
# step: 5400
#  discriminator loss: 0.6846410036087036
#  adversarial loss: 0.7634159326553345
#
# step: 5500
#  discriminator loss: 0.6593109965324402
#  adversarial loss: 0.895633339881897
#
# step: 5600
#  discriminator loss: 0.7372224926948547
#  adversarial loss: 0.8454723358154297
#
# step: 5700
#  discriminator loss: 0.700589656829834
#  adversarial loss: 0.8167566061019897
#
# step: 5800
#  discriminator loss: 0.695635199546814
#  adversarial loss: 0.8136094808578491
#
# step: 5900
#  discriminator loss: 0.6901144981384277
#  adversarial loss: 0.8321390151977539
#
# step: 6000
#  discriminator loss: 0.6704460382461548
#  adversarial loss: 0.8472785949707031
#
# step: 6100
#  discriminator loss: 0.6783407926559448
#  adversarial loss: 0.7612006664276123
#
# step: 6200
#  discriminator loss: 0.6673898696899414
#  adversarial loss: 0.8394218683242798
#
# step: 6300
#  discriminator loss: 0.6694530248641968
#  adversarial loss: 0.7649083137512207
#
# step: 6400
#  discriminator loss: 0.7215973138809204
#  adversarial loss: 0.753487229347229
#
# step: 6500
#  discriminator loss: 0.6480290293693542
#  adversarial loss: 0.7640359997749329
#
# step: 6600
#  discriminator loss: 0.7136634588241577
#  adversarial loss: 0.7883954048156738
#
# step: 6700
#  discriminator loss: 0.6822646856307983
#  adversarial loss: 0.736038088798523
#
# step: 6800
#  discriminator loss: 0.750551700592041
#  adversarial loss: 1.0741134881973267
#
# step: 6900
#  discriminator loss: 0.6876653432846069
#  adversarial loss: 0.7760009169578552
#
# step: 7000
#  discriminator loss: 0.6895691156387329
#  adversarial loss: 0.8754869699478149
#
# step: 7100
#  discriminator loss: 0.6604289412498474
#  adversarial loss: 0.8228530883789062
#
# step: 7200
#  discriminator loss: 0.6987627148628235
#  adversarial loss: 0.9085426330566406
#
# step: 7300
#  discriminator loss: 0.6844340562820435
#  adversarial loss: 0.8773273229598999
#
# step: 7400
#  discriminator loss: 0.7098557353019714
#  adversarial loss: 1.0483503341674805
#
# step: 7500
#  discriminator loss: 0.6562260985374451
#  adversarial loss: 0.8248419761657715
#
# step: 7600
#  discriminator loss: 0.6949642300605774
#  adversarial loss: 0.8030775785446167
#
# step: 7700
#  discriminator loss: 0.6893531680107117
#  adversarial loss: 1.0112369060516357
#
# step: 7800
#  discriminator loss: 0.6975061297416687
#  adversarial loss: 0.8826380968093872
#
# step: 7900
#  discriminator loss: 0.6974803805351257
#  adversarial loss: 0.7799969911575317
#
# step: 8000
#  discriminator loss: 0.6943482756614685
#  adversarial loss: 0.7845675349235535
#
# step: 8100
#  discriminator loss: 0.6714402437210083
#  adversarial loss: 0.7584130167961121
#
# step: 8200
#  discriminator loss: 0.7159817814826965
#  adversarial loss: 0.8836261630058289
#
# step: 8300
#  discriminator loss: 0.6714988946914673
#  adversarial loss: 0.7924073934555054
#
# step: 8400
#  discriminator loss: 0.6683080792427063
#  adversarial loss: 0.6206694841384888
#
# step: 8500
#  discriminator loss: 0.6656244397163391
#  adversarial loss: 0.8137229681015015
#
# step: 8600
#  discriminator loss: 0.6587392091751099
#  adversarial loss: 0.7250105738639832
#
# step: 8700
#  discriminator loss: 0.6724433898925781
#  adversarial loss: 0.7883869409561157
#
# step: 8800
#  discriminator loss: 0.6823655366897583
#  adversarial loss: 0.7782058715820312
#
# step: 8900
#  discriminator loss: 0.7326779961585999
#  adversarial loss: 0.7378044128417969
#
# step: 9000
#  discriminator loss: 0.6767799258232117
#  adversarial loss: 0.7690595388412476
#
# step: 9100
#  discriminator loss: 0.7853561043739319
#  adversarial loss: 1.0983575582504272
#
# step: 9200
#  discriminator loss: 0.6533552408218384
#  adversarial loss: 0.8153403401374817
#
# step: 9300
#  discriminator loss: 0.7084773778915405
#  adversarial loss: 0.8106791377067566
#
# step: 9400
#  discriminator loss: 0.7053667902946472
#  adversarial loss: 0.7182857990264893
#
# step: 9500
#  discriminator loss: 0.6639760136604309
#  adversarial loss: 0.8142701387405396
#
# step: 9600
#  discriminator loss: 0.6858206987380981
#  adversarial loss: 0.7469800710678101
#
# step: 9700
#  discriminator loss: 0.6931620836257935
#  adversarial loss: 0.7658615112304688
#
# step: 9800
#  discriminator loss: 0.6993794441223145
#  adversarial loss: 0.703991711139679
#
# step: 9900
#  discriminator loss: 0.7003814578056335
#  adversarial loss: 0.8271970748901367

# %% [markdown]
# #### 이미지 생성을 통한 시각화

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - 잠재 공간에서 랜덤한 포인트를 샘플링

# %%
random_latent_vectors = np.random.normal(size=(10,latent_dim))

# %% [markdown]
# - 가짜 이미지로 디코딩

# %%
generated_images = generator.predict(random_latent_vectors)

# %%
print(generated_images.shape)
# Out:
# (10, 32, 32, 3)

# %%
plt.figure(figsize=(20,8))
for i in range(generated_images.shape[0]):
  plt.subplot(2,5,i+1)
  img = image.array_to_img(generated_images[i] * 255., scale= False)
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])

plt.show()
