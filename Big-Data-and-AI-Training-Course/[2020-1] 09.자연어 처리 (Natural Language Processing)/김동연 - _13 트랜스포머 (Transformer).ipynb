# %% [markdown]
# # 트랜스포머 (Transformer)
#
# * 참고: https://wikidocs.net/31379

# %% [markdown]
# * attention mechanism은 seq2seq의 입력 시퀀스 정보 손실을 보정해주기 위해 사용됨
# * attention mechanism을 보정 목적이 아닌, 인코더와 디코더로 구성한 모델이 바로 트랜스포머
# * 트랜스포머는 RNN을 사용하지 않고 인코더와 디코더를 설계하였으며, 성능도 RNN보다 우수함

# %% [markdown]
# ## 포지셔널 인코딩

# %% [markdown]
# * 기존의 RNN은 단어의 위치를 따라 순차적으로 입력받아 단어의 위치정보를 활용할 수 있었음
# * 트랜스포머의 경우, RNN을 활용하지 않았기 때문에 단어의 위치정보를 다른 방식으로 줄 필요가 있음
# * 이를 위해 **각 단어의 임베딩 벡터에 위치 정보들을 더하게 되는데** 이를 포지셔널 인코딩이라 함
# * 보통 포지셔널 인코딩은 sin, cos을 이용하여 계산

# %%
def positional_encoding(dim, sentence_length):
  encoded_vec = np.array([pos / np.power(10000, 2 * i / dim) for pos in range(sentence_length) for i in range(dim)])
  encoded_vec[::2] = np.sin(encoded_vec[::2])
  encoded_vec[1::2] = np.cos(encoded_vec[1::2])
  return tf.constant(encoded_vec.reshape([sentence_length, dim]), dtype=tf.float32)

# %% [markdown]
# ## 레이어 정규화

# %% [markdown]
# *  레이어 정규화에서는 텐서의 마지막 차원에 대해 평균과 분산을 구하고, 이 값을 통해 값을 정규화함
# *  해당 정규화를 각 층의 연결에 편리하게 적용하기 위해 함수화한 `sublayer_connection()`을 선언

# %%
def layer_norm(inputs, eps=1e-6):
  feature_shape = inputs.get_shape()[-1:]
  mean = tf.keras.backend.mean(inputs, [-1], keepdims=True)
  std = tf.keras.backend.std(inputs, [-1], keepdims=True)
  beta = tf.Variable(tf.zeros(feature_shape), trainable=False)
  gamma = tf.Variable(tf.ones(feature_shape), trainable=False)
  return gamma * (inputs - mean) / (std + eps) + beta

# %%
def sublayer_connection(inputs, sublayer, dropout = 0.2):
  outputs = layer_norm(inputs + tf.keras.layers.Dropout(dropout)(sublayer))
  return outputs

# %% [markdown]
# ## 어텐션

# %% [markdown]
# *   트랜스포머 모델의 핵심이 되는 부분
# *   트랜스포머에서는 multi-head attention과 self attention이라는 개념을 사용
#   1.   multi-head attention
#       * 디코더가 가지는 차원을 나누어 병렬로 어텐션을 진행
#       *  마지막엔 병렬로 각 진행해 얻은 어텐션 헤드를 모두 연결
#       * 이로 인해 다양한 시각에서 정보를 수집할 수 있는 효과를 얻음
#   2.   self attention
#       *   일반적인 어텐션의 경우, 특정 시점의 디코더 은닉상태와 모든 시점의 인코더 은닉상태를 활용
#       *   이는 입력 문장과 다른 문장에 존재하는 단어간의 어텐션을 의미함
#       *   반면 self attention은 은닉 상태를 동일하게 하여 어텐션을 진행
#       *   이는 입력 문장 내 단어간의 어텐션을 의미함
#
#
#
#
# *   트랜스포머 제안 논문에서는 scaled-dot product attention을 활용해 모델을 작성함

# %% [markdown]
# ### scaled-dot product attention 구현

# %% [markdown]
# * scaled-dot product attention은 앞서 학습한 dot product attention과 거의 유사함
# * 단 attention을 진행할 때 어텐션 스코어를 계산할 때 내적 값을 정규화
# * 트랜스포머에서는 정규화할 때 K 벡터(=디코더 셀의 은닉 상태)의 차원을 루트를 취한 값을 사용

# %%
def scaled_dot_porduct_attention(query, key, value, masked=False):
  key_dim_size = float(key.get_shape().as_list()[-1])
  key = tf.transpose(key, perm=[0,2,1])

  outputs = tf.matmul(query, key) / tf.sqrt(key_dim_size)

  if masked:
    diag_vals = tf.ones_like(outputs[0,:,:])
    tril = tf.linalg.LinearOperatorLowerTriangular(diag_vals).to_dense()
    masks = tf.tile(tf.expand_dims(tril, 0),[tf.shape(outputs)[0],1,1])
    paddings = tf.ones_like(masks) * (-2**30)
    outputs = tf.where(tf.equal(masks,0), paddings, outputs)

  attention_map = tf.nn.softmax(outputs)
  return tf.matmul(attention_map, value)

# %% [markdown]
# ### multi-head attention 구현

# %% [markdown]
# * multi-head attention의 구현 과정
#   1. query, key, value에 해당하는 값을 받고, 해당 값에 해당하는 행렬 생성
#   2. 생성된 행렬들을 heads에 해당하는 수만큼 분리
#   3. 분리한 행렬들에 대해 각각 어텐션을 수행
#   4. 각 어텐션 결과들을 연결해 최종 어텐션 결과 생성

# %%
def multi_head_attention(query, key, value, num_units, heads, masked=False):
  query = tf.keras.layers.Dense(num_units, activation=tf.nn.relu)(query)
  key = tf.keras.layers.Dense(num_units, activation=tf.nn.relu)(key)
  value = tf.keras.layers.Dense(num_units, activation=tf.nn.relu)(value)

  query = tf.concat(tf.split(query, heads, axis=-1), axis=0)
  key = tf.concat(tf.split(key, heads, axis=-1), axis=0)
  value = tf.concat(tf.split(value, heads, axis=-1), axis=0)

  attention_map = scaled_dot_porduct_attention(query, key, value, masked)
  attn_outputs = tf.concat(tf.split(attention_map, heads, axis=0), axis=-1)
  attn_outputs = tf.keras.layers.Dense(num_units, activation=tf.nn.relu)(attn_outputs)

  return attn_outputs

# %% [markdown]
# ## 포지션-와이즈 피드 포워드 신경망

# %% [markdown]
# *   multi-head attention의 결과인 행렬을 입력받아 연산
# *   일반적인 완전 연결 신경망(Dense layer)를 사용
# *   position-wise FFNN은 인코더와 디코더에 모두 존재

# %%
def feed_forward(inputs, num_units):
  feature_shape = inputs.get_shape()[-1]
  inner_layer = tf.keras.layers.Dense(num_units, activation=tf.nn.relu)(inputs)
  outputs = tf.keras.layers.Dense(feature_shape)(inner_layer)
  return outputs

# %% [markdown]
# ## 인코더

# %% [markdown]
# * 인코더는 하나의 어텐션을 사용
#   + encoder self-attention (multi-head self-attention과 동일)

# %%
def encoder_module(inputs, model_dim, ffn_dim, heads):
  self_attn = sublayer_connection(inputs, multi_head_attention(inputs, inputs, inputs, model_dim,heads))
  outputs = sublayer_connection(self_attn, feed_forward(self_attn,ffn_dim))
  return outputs

def encoder(inputs, model_dim, ffn_dim, heads, num_layers):
  outputs = inputs
  for i in range(num_layers):
    outputs = encoder_module(outputs, model_dim, ffn_dim, heads)
  return outputs

# %% [markdown]
# ## 디코더

# %% [markdown]
# * 디코더는 다음과 같은 구성의 반복으로 이루어짐
#   1. masked decoder self-attention
#   2. encoder-decoder attention
#   3. position-wise FFNN
#
# * 디코더에서는 2종류의 어텐션을 사용
#   1.   masked decoder self-attention
#     *   디코더에서는 인코더와는 달리 순차적으로 결과를 만들어 내야하기 때문에 다른 어텐션 방법을 사용함
#     *   디코더 예측 시점 이후의 위치에 attention을 할 수 없도록 masking 처리
#     *   결국 예측 시점에서 예측은 미리 알고 있는 위치까지만의 결과에 의존
#   2.   encoder-decoder attention
#     *   앞서 설명한 multi-head attention과 동일

# %%
def decoder_module(inputs, encoder_outputs, model_dim, ffn_dim, heads):
  masked_self_attn = sublayer_connection(inputs,
                                         multi_head_attention(inputs, inputs, inputs,
                                                              model_dim, heads, masked=True))
  self_attn = sublayer_connection(masked_self_attn,
                                  multi_head_attention(masked_self_attn,
                                                       encoder_outputs,
                                                       encoder_outputs,
                                                       model_dim, heads))
  outputs = sublayer_connection(self_attn, feed_forward(self_attn, ffn_dim))
  return outputs

def decoder(inputs, encoder_outputs, model_dim, ffn_dim, heads, num_layers):
  outputs = inputs
  for i in range(num_layers):
    outputs = decoder_module(outputs, encoder_outputs, model_dim, ffn_dim, heads)

  return outputs

# %% [markdown]
# ## 트랜스포머를 활용한 챗봇

# %% [markdown]
# ### konlpy 라이브러리

# %% [markdown]
# *    한글을 처리하기 위해 konlpy 라이브러리 설치

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.6/dist-packages (0.5.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.4.4)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.1.2)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (3.9.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.5)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)

# %% [markdown]
# ### 데이터 준비

# %% [markdown]
# * 처리에 필요한 각종 변수 선언
# * filters에 해당되는 문자를 걸러주는 정규 표현식 컴파일

# %%
import re
import tensorflow as tf

filters = '([~.,!?\'":;)(])'
PAD = '<PADDING>'
STD = '<START>'
END = '<END>'
UNK = '<UNKNOWN>'

PAD_INDEX = 0
STD_INDEX = 0
END_INDEX = 0
UNK_INDEX = 0

MARKER = [PAD, STD, END, UNK]
CHANGE_FILTER = re.compile(filters)

# %% [markdown]
# * 주소에서 데이터를 가져오는 `load_data()` 함수 선언

# %%
from sklearn.model_selection import train_test_split
def load_data(data_path):
  data_df = pd.read_csv(data_path, header=0)
  question, answer = list(data_df['Q']), list(data_df['A'])
  train_input, eval_input, train_label, eval_label = train_test_split(question, answer,
                                                                      test_size=0.33,
                                                                      random_state=111)
  return train_input, train_label, eval_input, eval_label

# %% [markdown]
# * 처리에 필요한 단어 사전을 생성하는 `load_vocab()` 함수 선언

# %%
def load_vocabulary(data_path):
  data_df = pd.read_csv(data_path, encoding='utf-8')
  question, answer = list(data_df['Q']), list(data_df['A'])
  if tokenize_as_morph:
    question = prepro_like_morphlized(question)
    answer = prepro_like_morphlized(answer)

  data = []
  data.extend(question)
  data.extend(answer)
  words = data_tokenizer(data)
  words = list(set(words))
  words[:0] = MARKER
  
  char2idx = {char:idx for idx, char in enumerate(words)}
  idx2char = {idx:char for idx, char in enumerate(words)}
  return char2idx, idx2char, len(char2idx)

# %% [markdown]
# * 문자열 데이터를 학습에 사용될 수 있도록 변현하는 `prepro_like_morphlized()` 함수 선언

# %%
from konlpy.tag import Okt#openkoreatext

def prepro_like_morphlized(data):
  morph_analyzer = Okt()
  result_data = list()
  for seq in data:
    morphlized_seq = ' '.join(morph_analyzer.morphs(seq.replace(' ','')))
    result_data.append(morphlized_seq)
  return result_data

# %% [markdown]
# * 단어 사전을 만들기 위해 단어들을 분리하는 `data_tokenizer()` 함수 선언

# %%
def data_tokenizer(data):
  words = []
  for sentence in data:
    sentence = re.sub(CHANGE_FILTER, '', sentence)
    for word in sentence.split():
      words.append(word)
  return [word for word in words if word]

# %% [markdown]
# * encoder의 입력을 구성하기 위한 함수 `enc_processing()` 선언

# %%
import numpy as np

def enc_processing(value, dictionary):
  sequences_input_index = []
  sequences_length = []

  if tokenize_as_morph:
    value = prepro_like_morphlized(value)

  for sequence in value:
    sequence = re.sub(CHANGE_FILTER,'',sequence)
    sequence_index = []
    for word in sequence.split():
      if dictionary.get(word) is not None:
        sequence_index.extend([dictionary[word]])
      else:
        sequence_index.extend([dictionary[UNK]])
    
    if len(sequence_index) > max_len:
      sequence_index = sequence_index[:max_len]
    
    sequences_length.append(len(sequence_index))
    sequence_index += (max_len - len(sequence_index)) * [dictionary[PAD]]
    sequences_input_index.append(sequence_index)
  return np.asarray(sequences_input_index), sequences_length

# %% [markdown]
# * decoder의 입력을 구성하기 위한 함수 `dec_input_processing()` 선언

# %%
def dec_output_processing(value, dictionary):
  sequences_output_index = []
  sequences_length = []

  if tokenize_as_morph:
    value = prepro_like_morphlized(value)

  for sequence in value:
    sequence = re.sub(CHANGE_FILTER,'',sequence)
    sequence_index = [dictionary[STD]] + [dictionary[word] for word in sequence.split()]
    
    if len(sequence_index) > max_len:
      sequence_index = sequence_index[:max_len]
    
    sequences_length.append(len(sequence_index))
    sequence_index += (max_len - len(sequence_index)) * [dictionary[PAD]]
    sequences_output_index.append(sequence_index)
  return np.asarray(sequences_output_index), sequences_length

# %% [markdown]
# * decoder의 출력을 구성하기 위한 함수 `dec_target_processing()` 선언

# %%
def dec_target_processing(value, dictionary):
  sequences_target_index = []

  if tokenize_as_morph:
    value = prepro_like_morphlized(value)

  for sequence in value:
    sequence = re.sub(CHANGE_FILTER,'',sequence)
    sequence_index = [dictionary[word] for word in sequence.split()]
    
    if len(sequence_index) >= max_len:
      sequence_index = sequence_index[:max_len-1] + [dictionary[END]]
    else:
      sequence_index += [dictionary[END]]
    sequence_index += (max_len - len(sequence_index)) * [dictionary[PAD]]
    sequences_target_index.append(sequence_index)
  return np.asarray(sequences_target_index)

# %% [markdown]
# * 모델에 데이터를 효율적으로 투입하도록 `train_input_fn()`, `eval_input_fn()` 함수 선언
# * `rearrange()`는 dataset 객체가 데이터를 어떻게 변형시킬지 정의해둔 함수
# * dataset.map은 rearrange 함수를 기반으로 데이터를 변형

# %%
def train_input_fn(train_input_enc, train_output_enc, train_target_dec, batch_size):
  dataset = tf.compat.v1.data.Dataset.from_tensor_slices((train_input_enc, train_output_enc, train_target_dec))
  dataset = dataset.shuffle(buffer_size = len(train_input_enc))
  dataset = dataset.batch(batch_size)
  dataset = dataset.map(rearrange)
  dataset = dataset.repeat()
  iterator = dataset.make_one_shot_iterator()
  return iterator.get_next()

def eval_input_fn(eval_input_enc, eval_output_enc, eval_target_dec, batch_size):
  dataset = tf.compat.v1.data.Dataset.from_tensor_slices((eval_input_enc, eval_output_enc, eval_target_dec))
  dataset = dataset.shuffle(buffer_size = len(eval_input_enc))
  dataset = dataset.batch(batch_size)
  dataset = dataset.map(rearrange)
  dataset = dataset.repeat(1)
  iterator = dataset.make_one_shot_iterator()
  return iterator.get_next()

def rearrange(input, output, target):
  features = {'input':input, 'output':output}
  return features, target

# %% [markdown]
# * 모델의 예측은 배열로 생성되기 때문에 이를 확인하기 위해선 문자열로 변환이 필요
# * 예측을 문자열로 변환해주는 `pred2string()` 함수 선언

# %%
def pred2string(value, dictionary):
  sentence_string = []
  is_finished = False
  for v in value:
    sentence_string = [dictionary[index] for index in v['indexs']]
  
  answer = ''
  for word in sentence_string:
    if word == END:
      is_finished = True
      break

    if word != PAD and word != END:
      answer += word
      answer += ' '

  print(answer)
  return answer , is_finished

# %% [markdown]
# * 챗봇 데이터 URL: https://raw.githubusercontent.com/songys/Chatbot_data/master/ChatbotData%20.csv
# * 데이터 주소에서 데이터를 읽어들여 단어 사전과 사용 데이터 구성

# %%
import pandas as pd

tokenize_as_morph = True

data_path = 'https://raw.githubusercontent.com/songys/Chatbot_data/master/ChatbotData%20.csv'

char2idx, idx2char, len_vocab = load_vocabulary(data_path)

train_input, train_label, eval_input, eval_label = load_data(data_path)

# %%
idx2char
# Out:
# {0: '<PADDING>',
#  1: '<START>',
#  2: '<END>',
#  3: '<UNKNOWN>',
#  4: '프사',
#  5: '변함이',
#  6: '늙어가고있어요',
#  7: '댄디',
#  8: '보이는게',
#  9: '진행',
#  10: '실망하게',
#  11: '사귀는',
#  12: '먹은대로',
#  13: '이어질수도',
#  14: '일거라',
#  15: '이두',
#  16: '하고싶대',
#  17: '남아있나',
#  18: '라인',
#  19: '대가',
#  20: '떠났네',
#  21: '깔끔히',
#  22: '받아들여야하나',
#  23: '소중하던',
#  24: '보아',
#  25: '어려울거',
#  26: '열려',
#  27: '내릴까봐',
#  28: '말랐는지',
#  29: '벗겨져',
#  30: '좋았겠네요',
#  31: '소중한',
#  32: '공률',
#  33: '그린',
#  34: '서운한거를',
#  35: '다가오죠',
#  36: '가릴까',
#  37: '아픈것만큼',
#  38: '답장',
#  39: '덕',
#  40: '덮었어',
#  41: '두번째',
#  42: '좋아하게하는',
#  43: '기대하게되',
#  44: '안됨',
#  45: '안햇',
#  46: '입금',
#  47: '보고싶었던',
#  48: '잊어버리는것이',
#  49: '확실해졌네',
#  50: '홈쇼핑',
#  51: '그런',
#  52: '떠난',
#  53: '만날수도',
#  54: '나무',
#  55: '찍는',
#  56: '식은건',
#  57: '확실할',
#  58: '쉬고나면',
#  59: '해야하네요',
#  60: '너무함',
#  61: '좋아하고',
#  62: '건말',
#  63: '이서',
#  64: '물리',
#  65: '평화',
#  66: '되가',
#  67: '맞는데',
#  68: '기오',
#  69: '감으세요',
#  70: '격식',
#  71: '만남을거예요',
#  72: '헤어지고서',
#  73: '나가는게',
#  74: '옴',
#  75: '필요할거',
#  76: '조금',
#  77: '사줘요',
#  78: '하던',
#  79: '없거든',
#  80: '사소한',
#  81: '하겠네요',
#  82: '편해지겠지',
#  83: '그러는',
#  84: '하고있어',
#  85: '얇아',
#  86: '도와주세',
#  87: '사귀자',
#  88: '바쁘게',
#  89: '비',
#  90: '보고싶어',
#  91: '덤덤한데',
#  92: '제로',
#  93: '올거예요',
#  94: '생기기',
#  95: '꼴',
#  96: '피어싱',
#  97: '센터',
#  98: '놔줄라고',
#  99: '앞서서',
#  100: '질린다네',
#  101: '해주겠죠',
#  102: '태연히',
#  103: '이직',
#  104: '덜하는게',
#  105: '좋아하고있어요',
#  106: '받고싶어해',
#  107: '누락',
#  108: '남녀',
#  109: '난또',
#  110: '지웠을수도',
#  111: '자랑',
#  112: '우연히',
#  113: '졸업사진',
#  114: '바꿀까',
#  115: '아픔을지니',
#  116: '라고',
#  117: '밟는',
#  118: '기다리지도',
#  119: '떠났으면',
#  120: '속상했겠어요',
#  121: '끝내는건',
#  122: '모든',
#  123: '호수',
#  124: '직한',
#  125: '잘생긴건',
#  126: '바뀌고싶어',
#  127: '같으면',
#  128: '진행중',
#  129: '꼼꼼해',
#  130: '도자기',
#  131: '되는듯',
#  132: '가어디',
#  133: '라디오',
#  134: '이니까',
#  135: '내든',
#  136: '이겨야',
#  137: '험해',
#  138: '보일까',
#  139: '보는게',
#  140: '그리울거라',
#  141: '스팸메일',
#  142: '동시',
#  143: '있겠지요',
#  144: '태어났어요',
#  145: '다가갔네요',
#  146: '쓰려고운을',
#  147: '미워해도',
#  148: '두려운가요',
#  149: '기대하지마라',
#  150: '키우는거',
#  151: '안되었는데',
#  152: '찹하네',
#  153: '사귈수있을까요',
#  154: '욕심',
#  155: '안쪽',
#  156: '벚꽃놀이',
#  157: '이러니',
#  158: '세는것',
#  159: '금도',
#  160: '애완동물',
#  161: '했지만',
#  162: '많았을거라',
#  163: '없는거아는데도',
#  164: '가랑비',
#  165: '먹고살아요',
#  166: '탁트인',
#  167: '보여주고싶어',
#  168: '해야하는데',
#  169: '리다',
#  170: '둬',
#  171: '같은우리',
#  172: '있겠지',
#  173: '청',
#  174: '든거',
#  175: '굳이말',
#  176: '친한친구',
#  177: '두려워져요',
#  178: '잊지못하는',
#  179: '상하',
#  180: '말안하고',
#  181: '왔어요',
#  182: '돌보세요',
#  183: '아프겠지만',
#  184: '떨어진거',
#  185: '끊고다',
#  186: '당한거',
#  187: '발레',
#  188: '사주지',
#  189: '정도를만났는데잘이해가안가',
#  190: '재밌다고',
#  191: '만나는것도',
#  192: '가망',
#  193: '헤어스타일',
#  194: '잠자리',
#  195: '고하세요',
#  196: '벌써',
#  197: '그만',
#  198: '당연히',
#  199: '반항',
#  200: '자신',
#  201: '지옥',
#  202: '치열한',
#  203: '골랐어',
#  204: '가져가세요',
#  205: '필요한거겠죠',
#  206: '받니',
#  207: '어디서',
#  208: '3일',
#  209: '비꼬는데',
#  210: '하고도',
#  211: '찬성',
#  212: '이었겠지만',
#  213: '간당간당',
#  214: '공채',
#  215: '시생',
#  216: '완벽해지고',
#  217: '청소',
#  218: '어느덧',
#  219: '없다가있어서',
#  220: '짜는거',
#  221: '신었는',
#  222: '되어가는',
#  223: '할수있을지',
#  224: '달았습니다',
#  225: '당연한줄아네',
#  226: '되어가길',
#  227: '만나줄까',
#  228: '되겠어',
#  229: '지워',
#  230: '닿네',
#  231: '질리',
#  232: '찍혔을까',
#  233: '화려하지',
#  234: '쉬워',
#  235: '이정',
#  236: '회원',
#  237: '거드세요',
#  238: '가치관',
#  239: '참아오고있는데',
#  240: '답답할거예요',
#  241: '알아볼거예요',
#  242: '그렇다는',
#  243: '생겼더라',
#  244: '비겁한것은',
#  245: '깨졌는데다',
#  246: '공항',
#  247: '떠나갔어',
#  248: '심히오세요',
#  249: '흘러가죠',
#  250: '힘들고',
#  251: '조심해야겠다',
#  252: '잊으려면',
#  253: '갔는지',
#  254: '잘수있으면',
#  255: '맞춤법',
#  256: '잠이안오네',
#  257: '시키세요',
#  258: '안좋더라도',
#  259: '안좋았어',
#  260: '흔하지',
#  261: '서고',
#  262: '하고싶진',
#  263: '어지러워',
#  264: '매듭',
#  265: '담을수',
#  266: '있는데다',
#  267: '있을거니',
#  268: '도도하게하는게',
#  269: '좀쉬',
#  270: '많겠어요',
#  271: '변기',
#  272: '학회',
#  273: '공공장소',
#  274: '찾아왔어',
#  275: '같대',
#  276: '데려다주',
#  277: '반만났는데결혼하자고해도될까',
#  278: '너무하는게',
#  279: '기다려야죠',
#  280: '알겠네',
#  281: '할줄아는거',
#  282: '서글픈',
#  283: '근',
#  284: '기다립니다',
#  285: '했었으니까',
#  286: '는',
#  287: '라는',
#  288: '보았어',
#  289: '가려고',
#  290: '가슴',
#  291: '우선',
#  292: '이지만',
#  293: '부러',
#  294: '좋아하는지잘',
#  295: '개사',
#  296: '치우고싶어',
#  297: '맞춰주는',
#  298: '식은',
#  299: '춤',
#  300: '빼빼로데이',
#  301: '저물고',
#  302: '된여자친구랑이별',
#  303: '필요',
#  304: '복수',
#  305: '않아요',
#  306: '온다고하는데',
#  307: '놀자',
#  308: '말수',
#  309: '마세요',
#  310: '짰어',
#  311: '블랙데이',
#  312: '어색한',
#  313: '많을까',
#  314: '때론',
#  315: '가네여',
#  316: '있었지요',
#  317: '에드',
#  318: '챙기기',
#  319: '일이이',
#  320: '뭐라고하던가요',
#  321: '되어있지',
#  322: '통',
#  323: '면도기',
#  324: '올리고싶다',
#  325: '마시며',
#  326: '나는못',
#  327: '귀로',
#  328: '서못',
#  329: '도움',
#  330: '열고',
#  331: '살인',
#  332: '꿔주라',
#  333: '보통',
#  334: '안하는게',
#  335: '팔뚝',
#  336: '꿈을안',
#  337: '코스터',
#  338: '에선',
#  339: '우울한',
#  340: '되지',
#  341: '수당',
#  342: '도충',
#  343: '일기',
#  344: '잊으려',
#  345: '7년',
#  346: '연하가아니라',
#  347: '조깅',
#  348: '싫고',
#  349: '재밌을거',
#  350: '아프게도',
#  351: '아껴주셨나',
#  352: '먼데',
#  353: '나가는거예요',
#  354: '매정해졌어요',
#  355: '궁금증',
#  356: '신분',
#  357: '태닝할까',
#  358: '캔',
#  359: '한다고',
#  360: '차였는데',
#  361: '소중한것을',
#  362: '안자요',
#  363: '쉽지가',
#  364: '안가지고',
#  365: '하는군요',
#  366: '터졌네',
#  367: '기울여',
#  368: '이어나가는게',
#  369: '긴머리',
#  370: '다니니까',
#  371: '잡고싶지만',
#  372: '정확히',
#  373: '같기는해',
#  374: '아끼는게',
#  375: '같습니다',
#  376: '행복할',
#  377: '평안했던',
#  378: '사가',
#  379: '잃을까봐',
#  380: '자하',
#  381: '두셔요',
#  382: '받아야지',
#  383: '근사한',
#  384: '기다릴수있을까요',
#  385: '흡입',
#  386: '불행해',
#  387: '찰랑거렸으면',
#  388: '꾸죠',
#  389: '살더',
#  390: '야외',
#  391: '경쾌한',
#  392: '생각날테니',
#  393: '나폰겜',
#  394: '삶은',
#  395: '갈수',
#  396: '들려',
#  397: '치유',
#  398: '정도사귀었습니다',
#  399: '순진한',
#  400: '비추요',
#  401: '성공하고싶습니다',
#  402: '되었겠네요',
#  403: '분다',
#  404: '밸',
#  405: '떨면',
#  406: '늦는건',
#  407: '애버',
#  408: '쳐다봐',
#  409: '종료',
#  410: '도와줄거예요',
#  411: '달라졌겠죠',
#  412: '신청',
#  413: '빌려',
#  414: '드디어',
#  415: '약올라',
#  416: '도일',
#  417: '대',
#  418: '보셨어',
#  419: '되어가는데',
#  420: '필요없어요',
#  421: '때해선',
#  422: '구가',
#  423: '설렜을텐데',
#  424: '긴가민가한',
#  425: '그만했으면',
#  426: '기초',
#  427: '말이안',
#  428: '참는건',
#  429: '꾼건',
#  430: '줄임말보단',
#  431: '헤어지셨네요',
#  432: '오',
#  433: '헬',
#  434: '아닌것인가',
#  435: '나왕',
#  436: '떡볶이',
#  437: '갈수있을까',
#  438: '엉망',
#  439: '예전',
#  440: '후자',
#  441: '어차피',
#  442: '패턴',
#  443: '보지못',
#  444: '변하지',
#  445: '고고씽',
#  446: '나올수',
#  447: '꿰매',
#  448: '어렵지',
#  449: '남동생',
#  450: '견해',
#  451: '운남',
#  452: '다칠거예요',
#  453: '어떻하니',
#  454: '일인자',
#  455: '카드',
#  456: '써서',
#  457: '끝일',
#  458: '아쉬운',
#  459: '결국',
#  460: '할까',
#  461: '취를취',
#  462: '다가오고있다',
#  463: '패',
#  464: '종종',
#  465: '푸르',
#  466: '이상한가',
#  467: '어려울까',
#  468: '초라해',
#  469: '모실수있을까',
#  470: '피자',
#  471: '보낼수',
#  472: '보고야말았네',
#  473: '안함',
#  474: '지칩니다',
#  475: '오후',
#  476: '서도잘',
#  477: '통보',
#  478: '대상',
#  479: '만나자는말하',
#  480: '남잔',
#  481: '힘들건',
#  482: '먹고싶아',
#  483: '서소문',
#  484: '담기',
#  485: '같겠어요',
#  486: '른',
#  487: '가만히',
#  488: '맞춰가는거예요',
#  489: '했었는데',
#  490: '놓고우세요',
#  491: '킨',
#  492: '잠안',
#  493: '즐거운게',
#  494: '세다고',
#  495: '탈수있을것',
#  496: '무너진',
#  497: '뛰어넘을수있어요',
#  498: '보지',
#  499: '복잡하게',
#  500: '행복하고',
#  501: '충분한대',
#  502: '힘든게',
#  503: '받으려고',
#  504: '마주치겠음',
#  505: '짧아',
#  506: '아플까',
#  507: '필기구',
#  508: '되었다',
#  509: '왜못',
#  510: '그랬을수도',
#  511: '소나기',
#  512: '설레게하는',
#  513: '짐',
#  514: '잊는거야',
#  515: '듣는',
#  516: '했던건',
#  517: '밀려오라',
#  518: '하객',
#  519: '공시생',
#  520: '이또',
#  521: '깍',
#  522: '없을거예요',
#  523: '양말',
#  524: '만에진짜헤어지네',
#  525: '살려줘',
#  526: '끊었었는데',
#  527: '힘들지요',
#  528: '알았는데',
#  529: '소맥',
#  530: '으',
#  531: '않지요',
#  532: '이끌어가',
#  533: '보일거야',
#  534: '감사합니다',
#  535: '가꿔',
#  536: '밀려오는우울',
#  537: '짝녀',
#  538: '생겼으면',
#  539: '어딨나요',
#  540: '미세먼지',
#  541: '아니구',
#  542: 'sns',
#  543: '말아니면',
#  544: '볼때',
#  545: '떨쳐',
#  546: '먹었나',
#  547: '못자겠어',
#  548: '외로움',
#  549: '야경',
#  550: '살았는데도',
#  551: '웃으면서',
#  552: '안되지',
#  553: '답답증',
#  554: '쓰여',
#  555: '틀어놓고',
#  556: '오싹한',
#  557: '긴한데',
#  558: '영장',
#  559: '두려워하지말고',
#  560: '멀었나',
#  561: '감이네요',
#  562: '싸우면',
#  563: '좀있으면',
#  564: '보고싶으면',
#  565: '좋아했던만큼',
#  566: '그랬지',
#  567: '디져',
#  568: '스트레칭',
#  569: '활기찬',
#  570: '않고싶은데',
#  571: '주고받고',
#  572: '중요한데',
#  573: '어려운것',
#  574: '사귀고싶어',
#  575: '농활',
#  576: '잊기는',
#  577: '달을수있게',
#  578: '해가지는게',
#  579: '지긋지긋한',
#  580: '이란시간이무색해지네',
#  581: '나가는것도',
#  582: '프로필사진',
#  583: '꿀꿀해',
#  584: '놀고있습니다',
#  585: '고수',
#  586: '놓침',
#  587: '만담',
#  588: '슬퍼요',
#  589: '마주쳐',
#  590: '조건',
#  591: '조종사',
#  592: '살았네',
#  593: '적절해',
#  594: '년놈',
#  595: '월동',
#  596: '막힌다',
#  597: '불편하네',
#  598: '있더군',
#  599: '벽',
#  600: '결',
#  601: '않은',
#  602: '땐더',
#  603: '욕먹었어',
#  604: '만들어야지',
#  605: '다녀온',
#  606: '어떡하나',
#  607: '피는게',
#  608: '아자',
#  609: '흐른거',
#  610: '생각났어',
#  611: '초해',
#  612: '노후',
#  613: '타는거라',
#  614: '에아무도',
#  615: '나가라고',
#  616: '헤어지겠대',
#  617: '그럴거예요',
#  618: '받았나',
#  619: '모습',
#  620: '괜찮나요',
#  621: '코트',
#  622: '끊기는거',
#  623: '불안하면',
#  624: '먹',
#  625: '내려놓으렵니다',
#  626: '하려고해',
#  627: '했으면',
#  628: '벌주어',
#  629: '이른',
#  630: '있는데말거는',
#  631: '개',
#  632: '화하는게',
#  633: '인상',
#  634: '피부관리',
#  635: '들어와',
#  636: '기대가있으니까',
#  637: '놀면서',
#  638: '지우는',
#  639: '있길',
#  640: '중요한거',
#  641: '여린',
#  642: '주려해',
#  643: '있다는걸',
#  644: '마주치고싶지',
#  645: '달라지는건',
#  646: '좀질',
#  647: '비쌀까',
#  648: '와인',
#  649: '밀어',
#  650: '어땠을까',
#  651: '겨울나기',
#  652: '만났었지',
#  653: '띠',
#  654: '멈추지',
#  655: '받고',
#  656: '나이테',
#  657: '바쁘거나',
#  658: '자신있다면',
#  659: '락말락',
#  660: '보여주세요',
#  661: '지워지지',
#  662: '놓쳤다',
#  663: '바쁘네',
#  664: '버리겠다',
#  665: '말려줘',
#  666: '20분',
#  667: '짜증나는게',
#  668: '느려지는',
#  669: '잊어주겠어',
#  670: '없애는것도',
#  671: '깎아야지',
#  672: '냉면',
#  673: '알았는데도',
#  674: '달다',
#  675: '나머지',
#  676: '탈취',
#  677: '가만있어도',
#  678: '7',
#  679: '살아야',
#  680: '우울한것인가',
#  681: '중요한게',
#  682: '맺는',
#  683: '깨졌는지',
#  684: '지켜보세요',
#  685: '모',
#  686: '하면되',
#  687: '잊혀져가는게',
#  688: '잘해',
#  689: '아니면',
#  690: '드론',
#  691: '만나고싶어',
#  692: '쓰지도',
#  693: '말랭이',
#  694: '어언',
#  695: '잔해',
#  696: '어흥',
#  697: '잊는다는',
#  698: '나물',
#  699: '열',
#  700: '들었어',
#  701: '넣어',
#  702: '막차',
#  703: '고치면서',
#  704: '멋',
#  705: '주사',
#  706: '이마',
#  707: '기다릴수있을거예요',
#  708: '학식',
#  709: '쓰게',
#  710: '생긴',
#  711: '스케줄',
#  712: '마인드',
#  713: '얼마만큼',
#  714: '가재',
#  715: '가오',
#  716: '군데',
#  717: '좀노',
#  718: '해야하고',
#  719: '웃는',
#  720: '힘들었죠',
#  721: '오래',
#  722: '비집',
#  723: '에아',
#  724: '헤어진',
#  725: '떨치기',
#  726: '의아',
#  727: '물어보고싶어',
#  728: '아니지만',
#  729: '행복하게도',
#  730: '맘전',
#  731: '벌',
#  732: 'ㅜㅜ',
#  733: '전여자친구',
#  734: '줄이고싶어',
#  735: '들텐데요',
#  736: '접었습니다',
#  737: '덤덤해지는',
#  738: '한쪽',
#  739: '했길',
#  740: '즐기나',
#  741: '궁금해서',
#  742: '사귀고있지',
#  743: '간',
#  744: '짝녀나',
#  745: '줄어들거예요',
#  746: '해주고가네',
#  747: '필요없는',
#  748: '눈빛',
#  749: '나를오라고',
#  750: '닥쳐올',
#  751: '맞았어',
#  752: '맞춰지네',
#  753: '어장',
#  754: '드세요',
#  755: '무심하네',
#  756: '요구',
#  757: '정해진',
#  758: '입학식',
#  759: '헤어지려고',
#  760: '잘싸워',
#  761: '페메',
#  762: '부탁드려',
#  763: '제자리',
#  764: '변하니까',
#  765: '떠서',
#  766: '만날수있어',
#  767: '호칭',
#  768: '빗',
#  769: '현금영수증',
#  770: '벗어나자',
#  771: '금집앞',
#  772: '양식',
#  773: '잡았어',
#  774: '생텍쥐베리',
#  775: '경쟁자',
#  776: '허전함',
#  777: '카리스마',
#  778: '씹어야겠다',
#  779: '분하고',
#  780: '멀고해',
#  781: '감미로운',
#  782: '탱',
#  783: '해보세',
#  784: '없을거야',
#  785: '말통',
#  786: '연애환승이별',
#  787: '쓴',
#  788: '야하는',
#  789: '앉아있지',
#  790: '그때',
#  791: '들었는데',
#  792: '필요하겠지',
#  793: '치여',
#  794: '직접',
#  795: '자기전에',
#  796: '재밌겠어요',
#  797: '후련하겠어요',
#  798: '잊어버리나',
#  799: '쪽팔려',
#  800: '기대하지말',
#  801: '웃으면',
#  802: '생겼어요',
#  803: '사주세요',
#  804: '달되',
#  805: '다부질',
#  806: '한지',
#  807: '은한',
#  808: '고솔',
#  809: '돌아보는것',
#  810: '재밌는게',
#  811: '남기기',
#  812: '한',
#  813: '오히려',
#  814: '돕는',
#  815: '구속',
#  816: '애석하게도',
#  817: '푸석푸석해',
#  818: '꿈',
#  819: '친하게지내요',
#  820: '알아',
#  821: '만들었어',
#  822: '참답',
#  823: '만든야',
#  824: '먹네',
#  825: '재미있는거',
#  826: '아쉽겠네요',
#  827: '커져',
#  828: '쟁이',
#  829: '전남친',
#  830: '이용',
#  831: '물못',
#  832: '가능할거예요',
#  833: '마카롱',
#  834: '예민해서',
#  835: '플',
#  836: '꾸는데',
#  837: '빠짐',
#  838: '싫어하는데',
#  839: '흰',
#  840: '씹하면',
#  841: '부럽네요',
#  842: '쉽이',
#  843: '붙잡고싶어',
#  844: '만날줄',
#  845: '버티고계',
#  846: '찬거겠죠',
#  847: '메리',
#  848: '위축',
#  849: '질렀어',
#  850: '책좀',
#  851: '이란오랜기간연애를하다보니권태기가찾아오네',
#  852: '까먹었어',
#  853: '될줄',
#  854: '살찔까봐',
#  855: '부렸을까',
#  856: '전달',
#  857: '좋아하겠지',
#  858: '사귀고해어진지',
#  859: '동물',
#  860: '감수성',
#  861: '들수있으면',
#  862: '바뀌니',
#  863: '줘요',
#  864: '달도',
#  865: '밝혀지기',
#  866: '책보',
#  867: '않네요',
#  868: '좋아지고있어',
#  869: '하러가고싶다',
#  870: '따지기',
#  871: '2일',
#  872: '대출',
#  873: '0',
#  874: '좀구',
#  875: '주량',
#  876: '탑니다',
#  877: '어떻게도',
#  878: '로이',
#  879: '듣고싶다',
#  880: '야만',
#  881: '아픈데',
#  882: '꺼내기가',
#  883: '분해',
#  884: '왔어',
#  885: '쥐꼬리',
#  886: '먹을거하나도',
#  887: '되가는데',
#  888: '고의',
#  889: '돌릴수',
#  890: '무신',
#  891: '연애이별후',
#  892: '마지막',
#  893: '가벼워질수만',
#  894: '마시는',
#  895: '만나지못',
#  896: '젠더',
#  897: '클리',
#  898: '대학교',
#  899: '다쳤어',
#  900: '넘고',
#  901: '이기',
#  902: '들어서말을못하겠어',
#  903: '생리통',
#  904: '믿었어',
#  905: '않았다면',
#  906: '부자',
#  907: '바람둥이',
#  908: '새집',
#  909: '시려',
#  910: '털털',
#  911: '노는것',
#  912: '생생한데',
#  913: '길어서',
#  914: '많아지는',
#  915: '찾는다고',
#  916: '향해',
#  917: '좀덜',
#  918: '내려놓으면서',
#  919: '지쳐가는',
#  920: '내려',
#  921: '힘드셨겠어요',
#  922: '참못난',
#  923: '초콜릿선물',
#  924: '남기는것도',
#  925: '탄생',
#  926: '들까',
#  927: '보자',
#  928: '맛있어요',
#  929: '천일',
#  930: '부산',
#  931: '버리',
#  932: '대간',
#  933: '부족한가',
#  934: '야하네',
#  935: '돌아가고',
#  936: '차면',
#  937: '잼있는거는',
#  938: '좋지만은',
#  939: '빨간',
#  940: '어느덧주말이네요',
#  941: '주소',
#  942: '벗겨지지',
#  943: '힘들군요',
#  944: '마시지못',
#  945: '짠하고',
#  946: '예쁘게나',
#  947: '가리는',
#  948: '떨칠수도',
#  949: '괜찮습니다',
#  950: '끊은',
#  951: '난거아니야',
#  952: '믿고싶지',
#  953: '내서말',
#  954: '되니',
#  955: '나좀쩌는듯',
#  956: '즘',
#  957: '보려해',
#  958: '없죠',
#  959: '났는데',
#  960: '쐬고와',
#  961: '허례',
#  962: '대학가',
#  963: '와우',
#  964: '어떡하지',
#  965: '하고나니',
#  966: '남았을지도',
#  967: '돌아오고싶다는',
#  968: '아무렇게나',
#  969: '내딛으셨네요',
#  970: '찾아가고',
#  971: '깼어',
#  972: '느낄지',
#  973: '혼나는데',
#  974: '키스',
#  975: '좀깨',
#  976: '이넘었네',
#  977: '들어서줄까',
#  978: '명품',
#  979: '드리질',
#  980: '힘들겠죠',
#  981: '쉬운',
#  982: '복잡하겠어요',
#  983: '않기',
#  984: '나가서',
#  985: '끝내지못하는거죠',
#  986: '무난',
#  987: '심하지',
#  988: '타는거야',
#  989: '집사',
#  990: '4',
#  991: '손가락질',
#  992: '사는거죠',
#  993: '피곤한건',
#  994: '같은데내가',
#  995: '기만',
#  996: '힘든거네',
#  997: '하기는',
#  998: '틀리는',
#  999: '확실한지',
#  ...}

# %% [markdown]
# ### 모델 구성

# %% [markdown]
# * 앞서 작성한 트랜스포머 모델을 결합해 학습에 사용할 모델을 구성함

# %%
def model(features, labels, mode, params):
  TRAIN = mode == tf.estimator.ModeKeys.TRAIN
  EVAL = mode == tf.estimator.ModeKeys.EVAL
  PREDICT = mode == tf.estimator.ModeKeys.PREDICT

  position_encode = positional_encoding(params['embedding_size'], params['max_len'])
  if params['xavier_initializer']:
    embedding_initializer = 'glorot_normal'
  else:
    embedding_initializer = 'uniform'

  embedding = tf.keras.layers.Embedding(params['len_vocab'],
                                        params['embedding_size'],
                                        embeddings_initializer = embedding_initializer)
  x_embedded_matrix = embedding(features['input']) + position_encode
  y_embedded_matrix = embedding(features['output']) + position_encode

  encoder_outputs = encoder(x_embedded_matrix, params['model_hidden_size'], params['ffn_hidden_size'],
                            params['attention_head_size'],params['layer_size'])
  decoder_outputs = decoder(y_embedded_matrix,encoder_outputs ,params['model_hidden_size'],
                            params['ffn_hidden_size'],params['attention_head_size'],params['layer_size'])
  logits = tf.keras.layers.Dense(params['len_vocab'])(decoder_outputs)
  predict = tf.argmax(logits, 2)
  if PREDICT:
    predictions = {'indexs':predict,
                   'logits':logits}
    return tf.estimator.EstimatorSpec(mode, predictions=predictions)
  
  labels_ = tf.one_hot(labels, params['len_vocab'])
  loss = tf.reduce_mean(tf.compat.v1.nn.softmax_cross_entropy_with_logits_v2(logits=logits,labels=labels_))
  accuracy = tf.compat.v1.metrics.accuracy(labels=labels,predictions=predict)
  
  metrics = {'accuracy':accuracy}
  tf.summary.scalar('accuracy',accuracy[1])

  if EVAL:
    return tf.estimator.EstimatorSpec(mode, loss=loss, eval_metric_ops=metrics)
  assert TRAIN

  optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=params['learning_rate'])
  train_op = optimizer.minimize(loss, global_step=tf.compat.v1.train.get_global_step())
  return tf.estimator.EstimatorSpec(mode, loss=loss, train_op = train_op)

# %% [markdown]
# ### 모델 학습

# %% [markdown]
# *   필요한 각종 인자들을 설정
# *   인자에 따라 학습 결과가 달라질 수 있기 때문에 세심한 조정이 필요

# %%
max_len = 25
epoch = 5000
batch_size = 256
embedding_size = 100
model_hidden_size = 100
ffn_hidden_size = 100
attention_head_size = 100
lr = 0.001
layer_size = 3
xavier_initializer = True

# %% [markdown]
# *   앞서 선언한 processing 함수로 데이터를 모델에 투입할 수 있도록 가공
# *   평가 데이터에도 동일하게 가공

# %%
train_input_enc, train_input_enc_length = enc_processing(train_input, char2idx)
train_output_dec, train_output_dec_length = dec_output_processing(train_label, char2idx)
train_target_dec = dec_target_processing(train_label, char2idx)

eval_input_enc, eval_input_enc_length = enc_processing(eval_input, char2idx)
eval_output_dec, eval_output_dec_length = dec_output_processing(eval_label, char2idx)
eval_target_dec = dec_target_processing(eval_label, char2idx)

# %% [markdown]
# * 앞서 선언한 함수를 통해 모델을 선언하고 학습
# * `tf.estimator`를 사용해 간편하게 학습 모듈 구성

# %%
transformer = tf.estimator.Estimator(
    model_fn = model,
    params = {'embedding_size': embedding_size,
              'model_hidden_size': model_hidden_size,
              'ffn_hidden_size':ffn_hidden_size,
              'attention_head_size':attention_head_size,
              'learning_rate':lr,
              'len_vocab':len_vocab,
              'layer_size':layer_size,
              'max_len':max_len,
              'xavier_initializer':xavier_initializer}
)

# %% [markdown]
# * 학습한 모델을 사용해 챗봇을 사용
# * 예측 결과를 문자열로 변환할 때는 앞서 선언한 `pred2string()` 함수를 이용
# * 입력에 대한 응답이 생성되는 것을 확인할 수 있음

# %%
transformer.summary()

# %%
transformer.train(input_fn=lambda: train_input_fn(train_input_enc, train_output_dec, train_target_dec, batch_size), steps=epoch)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpt287typl/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 9.703392, step = 0
# INFO:tensorflow:global_step/sec: 5.87954
# INFO:tensorflow:loss = 1.6719353, step = 100 (17.011 sec)
# INFO:tensorflow:global_step/sec: 7.12318
# INFO:tensorflow:loss = 1.3008702, step = 200 (14.041 sec)
# INFO:tensorflow:global_step/sec: 7.13314
# INFO:tensorflow:loss = 1.262375, step = 300 (14.018 sec)
# INFO:tensorflow:global_step/sec: 7.12133
# INFO:tensorflow:loss = 1.0142003, step = 400 (14.042 sec)
# INFO:tensorflow:global_step/sec: 7.12657
# INFO:tensorflow:loss = 0.8503468, step = 500 (14.032 sec)
# INFO:tensorflow:global_step/sec: 7.03783
# INFO:tensorflow:loss = 0.7385056, step = 600 (14.209 sec)
# INFO:tensorflow:global_step/sec: 7.14426
# INFO:tensorflow:loss = 0.6633519, step = 700 (13.996 sec)
# INFO:tensorflow:global_step/sec: 7.14007
# INFO:tensorflow:loss = 0.5868687, step = 800 (14.010 sec)
# INFO:tensorflow:global_step/sec: 7.12121
# INFO:tensorflow:loss = 0.4012653, step = 900 (14.040 sec)
# INFO:tensorflow:global_step/sec: 7.11511
# INFO:tensorflow:loss = 0.33247975, step = 1000 (14.053 sec)
# INFO:tensorflow:global_step/sec: 7.08446
# INFO:tensorflow:loss = 0.2708087, step = 1100 (14.116 sec)
# INFO:tensorflow:global_step/sec: 7.13535
# INFO:tensorflow:loss = 0.21364364, step = 1200 (14.012 sec)
# INFO:tensorflow:global_step/sec: 7.16101
# INFO:tensorflow:loss = 0.16287619, step = 1300 (13.969 sec)
# INFO:tensorflow:global_step/sec: 7.15801
# INFO:tensorflow:loss = 0.10485104, step = 1400 (13.966 sec)
# INFO:tensorflow:global_step/sec: 7.18013
# INFO:tensorflow:loss = 0.074799255, step = 1500 (13.929 sec)
# INFO:tensorflow:global_step/sec: 7.13517
# INFO:tensorflow:loss = 0.058567677, step = 1600 (14.015 sec)
# INFO:tensorflow:global_step/sec: 7.13235
# INFO:tensorflow:loss = 0.043612022, step = 1700 (14.020 sec)
# INFO:tensorflow:global_step/sec: 7.02556
# INFO:tensorflow:loss = 0.02866474, step = 1800 (14.232 sec)
# INFO:tensorflow:global_step/sec: 7.01282
# INFO:tensorflow:loss = 0.022959525, step = 1900 (14.260 sec)
# INFO:tensorflow:global_step/sec: 7.13269
# INFO:tensorflow:loss = 0.017773494, step = 2000 (14.023 sec)
# INFO:tensorflow:global_step/sec: 7.1315
# INFO:tensorflow:loss = 0.014508443, step = 2100 (14.021 sec)
# INFO:tensorflow:global_step/sec: 7.10775
# INFO:tensorflow:loss = 0.014163085, step = 2200 (14.067 sec)
# INFO:tensorflow:global_step/sec: 7.14819
# INFO:tensorflow:loss = 0.0103652, step = 2300 (13.989 sec)
# INFO:tensorflow:global_step/sec: 7.1214
# INFO:tensorflow:loss = 0.008933433, step = 2400 (14.044 sec)
# INFO:tensorflow:global_step/sec: 7.1253
# INFO:tensorflow:loss = 0.009342345, step = 2500 (14.034 sec)
# INFO:tensorflow:global_step/sec: 7.11645
# INFO:tensorflow:loss = 0.008588206, step = 2600 (14.051 sec)
# INFO:tensorflow:global_step/sec: 7.12539
# INFO:tensorflow:loss = 0.0060559446, step = 2700 (14.035 sec)
# INFO:tensorflow:global_step/sec: 7.06949
# INFO:tensorflow:loss = 0.005856155, step = 2800 (14.145 sec)
# INFO:tensorflow:global_step/sec: 7.11745
# INFO:tensorflow:loss = 0.0056428243, step = 2900 (14.050 sec)
# INFO:tensorflow:global_step/sec: 7.06324
# INFO:tensorflow:loss = 0.004942328, step = 3000 (14.158 sec)
# INFO:tensorflow:global_step/sec: 7.04751
# INFO:tensorflow:loss = 0.0042761373, step = 3100 (14.191 sec)
# INFO:tensorflow:global_step/sec: 7.10674
# INFO:tensorflow:loss = 0.0044655227, step = 3200 (14.070 sec)
# INFO:tensorflow:global_step/sec: 7.11693
# INFO:tensorflow:loss = 0.46485215, step = 3300 (14.051 sec)
# INFO:tensorflow:global_step/sec: 7.12834
# INFO:tensorflow:loss = 0.045750074, step = 3400 (14.027 sec)
# INFO:tensorflow:global_step/sec: 7.13802
# INFO:tensorflow:loss = 0.018321464, step = 3500 (14.018 sec)
# INFO:tensorflow:global_step/sec: 7.13261
# INFO:tensorflow:loss = 0.008359902, step = 3600 (14.017 sec)
# INFO:tensorflow:global_step/sec: 7.14546
# INFO:tensorflow:loss = 0.0062043653, step = 3700 (13.993 sec)
# INFO:tensorflow:global_step/sec: 7.12728
# INFO:tensorflow:loss = 0.005140271, step = 3800 (14.029 sec)
# INFO:tensorflow:global_step/sec: 7.1189
# INFO:tensorflow:loss = 0.0049005267, step = 3900 (14.047 sec)
# INFO:tensorflow:global_step/sec: 7.14024
# INFO:tensorflow:loss = 0.003971658, step = 4000 (14.006 sec)
# INFO:tensorflow:global_step/sec: 7.11783
# INFO:tensorflow:loss = 0.0035227495, step = 4100 (14.049 sec)
# INFO:tensorflow:global_step/sec: 7.08335
# INFO:tensorflow:loss = 0.00412074, step = 4200 (14.115 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4226...
# INFO:tensorflow:Saving checkpoints for 4226 into /tmp/tmpt287typl/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4226...
# INFO:tensorflow:global_step/sec: 6.66262
# INFO:tensorflow:loss = 0.0044284477, step = 4300 (15.012 sec)
# INFO:tensorflow:global_step/sec: 7.05615
# INFO:tensorflow:loss = 0.0040131877, step = 4400 (14.169 sec)
# INFO:tensorflow:global_step/sec: 7.07386
# INFO:tensorflow:loss = 0.0033296824, step = 4500 (14.139 sec)
# INFO:tensorflow:global_step/sec: 7.10435
# INFO:tensorflow:loss = 0.003327083, step = 4600 (14.075 sec)
# INFO:tensorflow:global_step/sec: 7.13081
# INFO:tensorflow:loss = 0.0021817617, step = 4700 (14.024 sec)
# INFO:tensorflow:global_step/sec: 7.11802
# INFO:tensorflow:loss = 0.0018946796, step = 4800 (14.050 sec)
# INFO:tensorflow:global_step/sec: 7.11111
# INFO:tensorflow:loss = 0.0023090215, step = 4900 (14.060 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmpt287typl/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.0028340782.

# %%
eval_result = transformer.evaluate(input_fn=lambda: eval_input_fn(eval_input_enc, eval_output_dec, eval_target_dec, batch_size))
print('accuracy: {accuracy: 0.3f}'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-10-05T10:07:20Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 2.59962s
# INFO:tensorflow:Finished evaluation at 2020-10-05-10:07:23
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.86427474, global_step = 5000, loss = 1.53665
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmpt287typl/model.ckpt-5000
# accuracy:  0.864

# %% [markdown]
# ### 예측

# %% [markdown]
# * 학습한 모델을 사용해 챗봇을 사용
# * 예측 결과를 문자열로 변환할 때는 앞서 선언한 `pred2string()` 함수를 이용
# * 입력에 대한 응답이 생성되는 것을 확인할 수 있음

# %%
def chatbot(sentence):
  pred_input_enc, pred_input_enc_length = enc_processing([sentence],char2idx)
  pred_output_dec, pred_output_dec_length = dec_output_processing([''], char2idx)
  pred_target_dec = dec_target_processing([''], char2idx)

  for i in range(max_len):
    if i > 0:
      pred_output_dec, pred_output_dec_length = dec_output_processing([answer],char2idx)
      pred_target_dec = dec_target_processing([answer],char2idx)

    predictions = transformer.predict(input_fn=lambda: eval_input_fn(pred_input_enc, pred_output_dec, pred_target_dec, 1))
    answer, finished = pred2string(predictions, idx2char)

    if finished:
      break

  return answer

# %%
chatbot('안녕?')
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 세상
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 세상 에
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 세상 에 별별
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 세상 에 별별 사람
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 세상 에 별별 사람 들
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 세상 에 별별 사람 들 이다
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 세상 에 별별 사람 들 이다 있죠
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 세상 에 별별 사람 들 이다 있죠
# '세상 에 별별 사람 들 이다 있죠 '

# %%
chatbot('누구냐?')
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 는
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 는 마음
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 는 마음 을
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 는 마음 을 이어주는
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 는 마음 을 이어주는 위로
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 는 마음 을 이어주는 위로 봇
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 는 마음 을 이어주는 위로 봇 입니다
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 는 마음 을 이어주는 위로 봇 입니다
# '저 는 마음 을 이어주는 위로 봇 입니다 '

# %%
chatbot('뭐 먹었어?')
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 랑
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 랑 놀아서
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 랑 놀아서 그래요
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 저 랑 놀아서 그래요
# '저 랑 놀아서 그래요 '

# %%
chatbot('놀고 싶다')
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 마음
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 마음 이
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 마음 이 저
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 마음 이 저 몸
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 마음 이 저 몸 도
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 마음 이 저 몸 도 매력
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 마음 이 저 몸 도 매력 을
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 마음 이 저 몸 도 매력 을 어필
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 마음 이 저 몸 도 매력 을 어필 해보세요
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 마음 이 저 몸 도 매력 을 어필 해보세요
# '마음 이 저 몸 도 매력 을 어필 해보세요 '

# %%
chatbot('이제 그만 잘래')
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 정말
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 정말 안녕
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt287typl/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 정말 안녕
# '정말 안녕 '
