# %% [markdown]
# # BeautyfulSoup 네이버 블로그 스크래핑

# %% [markdown]
# ## 블로그 포스트 스크래핑 함수 정의

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import pandas as pd

def get_posts(query,page_num=10):
  url_query = quote(query)#utf-8 로 코딩 
  url = 'https://search.naver.com/search.naver?where=post&query=' + url_query

  post_df = pd.DataFrame(columns=('Ttile','Date','Blogger','Blog URL','Post URL','Post'))
  idx = 0
  
  for _ in range(0,page_num):
    search_url = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(search_url, 'html.parser')
    posts = soup.find_all('li',{'class':'sh_blog_top'})
    

    for post in posts:
      title = post.find('a',{'class':'sh_blog_title _sp_each_url _sp_each_title'}).get('title')
      date = post.find('dd',{'class':'txt_inline'}).get_text()
      blogger = post.find('a',{'class':'txt84'}).get_text()
      blog_url = post.find('a',{'class':'txt84'}).get('href')
      post_url = post.find('a',{'class':'url'}).get('href')
      post_link = urllib.request.urlopen(post_url).read()
      post_html = BeautifulSoup(post_link,'html.parser')

      for main_frame in post_html.select('iframe#mainFrame'):
        frame_url = 'https://blog.naver.com' + main_frame.get('src')
        post_text = urllib.request.urlopen(frame_url).read()
        post_html = BeautifulSoup(post_text,'html.parser')
        post_content_text = ''

        for post_content in post_html.find_all('div',{'class':'se-main-container'}):
          post_content_text = post_content.get_text()

        post_content_text = post_content_text.replace('\n','')
        post_content_text = post_content_text.replace('\t','')

        post_df.loc[idx] = [title,date,blogger,blog_url,post_url,post_content_text]
        idx += 1
        print('#',end='')

    try:
      next = soup.find('a',{'class':'next'}).get('href')
      url = 'https://search.naver.com/search.naver' + next
    except:
      break

  return post_df

# %% [markdown]
# ## 블로그 포스트 스크래핑 실행

# %%
query = input('검색질의 : ')
post_df = get_posts(query,4)
print('Done')
# Out:
# 검색질의 : 컴퓨터
# #################################Done

# %%
post_df
# Out:
#                                                 Ttile  ...                                               Post
# 0                                FHD 실무를 위한 영상편집용 컴퓨터  ...  영상편집용 컴퓨터​오늘은 유튜브등의 플랫폼에서 대표적으로 널리 쓰이고 있는, 192...
# 1   숯공장에서 온라인주문 확인할 저렴한 컴퓨터. 모니터 포함 30만원이하로.../ 라이...  ...  ​공장에서 온라인 주문만 하면 된다고 하여... 문의한 분이다. 알고보니 대략 8년...
# 2                               4K 작업에 최적화된 영상편집용 컴퓨터  ...  오늘은 성능과 가성비를 동시에 잡은 4K 영상편집용 컴퓨터를 소개해 드리겠습니다. ...
# 3                                  강남컴퓨터학원 꿈을 위한 한걸음!  ...  여태 다루고 있었던 전공과는무관하지만 그래도 배우고 싶었던게 있었어요혼자 시작하려 ...
# 4                     저렴하지만 뛰어난 성능을 갖춘 PC방 사양 조립식 컴퓨터  ...   Overview 부담 없는 가격, 강력한 성능 가성비 피시방 조립컴퓨터. 피시방 ...
# 5                     "면 마스크 써도 되나".. 세계 최고 슈퍼컴퓨터의 대답  ...  무더운 여름에 마스크까지 쓰는 게 즐거운 일은 아니다. 하지만 마스크를 쓰고 사회적...
# 6                         새 사무실 입주한 기념으로 애플 컴퓨터 FLEX!  ...  화장품 관련 회사를 운영하시는 대표님이 새로운 사무실을 입주하셔서 직접 사용할 컴퓨...
# 7                          부담없는 금액의 모니터 4개 지원 주식용 컴퓨터  ...  4모니터를 지원하면서도 저렴한 것이 포인트부담없는 금액의 주식용 컴퓨터  스켈핑, ...
# 8                 인텔10세대 i5 10400 포토샵 일러스트 그래픽용 조립컴퓨터  ...  안녕하세요~15년~ 같은자리 같은 위치에서 꾸준하게 컴퓨터를 제작하고 있는용산 조립...
# 9                           컴퓨터 화면 캡쳐 3가지 방법 알면 유용할걸?  ...  이번 시간에는 컴퓨터 화면 캡쳐 방법을 가이드 한다. 가족, 친구, 지인에게 PC ...
# 10                  수냉식 컴퓨터, NZXT KRAKEN X73 쿨러 사용 견적  ...   장마가 끝나고, 무더운 더위가 시작되었네요!​늦은 무더위라 조금만 기다리면 금방 ...
# 11                              I7+2060S 조합 고사양게임용컴퓨터  ...  고사양게임용컴퓨터​오늘은 일반적인 게이밍 피씨 옵션중에서도 조금 더, 나은 환경에서...
# 12  목소리부터 반듯한 인천 부목사님. 교회영상 실시간 영상편집을 위해 창고에 박혀 있단...  ...  ​(2020년 7월초에 작업한 컴퓨터)​​<목적>교회에서 실시간 방송할 컴퓨터로 업...
# 13                                스팀 게임을 위한 조립식컴퓨터 견적  ...  오늘은 높은 PC 성능을 요구하는 고사양 게임들을 쾌적하게 즐기기 위한 합리적인 구...
# 14  라이젠 9 3900X+녹투아 NH-D15 Chromax 강력한 퍼포먼스와 쿨링 성능...  ...   Overview 실시간 방송 및 영상편집을 위한 고성능 조립 컴퓨터 사양. 안녕하...
# 15                              활용도 높은 거실 컴퓨터  멋진 디자인  ...  편집디자인용으로 사용할 애플 컴퓨터 설치했습니다.며칠전 신형 아이맥이 발표되었는데 ...
# 16                           모니터를 최대 8개까지 지원하는 주식 컴퓨터  ...  FHD 8대, 4K 4대 사용이 가능한최대 8모니터 지원 주식 컴퓨터 코로나 때문에...
# 17        최고사양 I7 10700K RTX2080SUPER 게임용 방송용 조립컴퓨터출고  ...  안녕하세요~~용산 조립컴퓨터 전문매장 세븐컴피씨 입니다.​​게임용 고사양 하이앤드급...
# 18  (조립컴퓨터 추천) 인텔 i5 10400 + GTX 1660 SUPER 고성능 배그...  ...  ​​안녕하세요장마가 이리 긴해는 처음인 것 같은 요즘 하루가 멀다 하고 비가 내리고...
# 19                            프리미어 프로를 위한 영상편집 컴퓨터 견적  ...   영상편집 컴퓨터​오늘은 프리미어 프로, 에펙, 베가스, 에디우스등의 에디팅툴을 다...
# 20   IPS 패널로 화질 만족감을 높이다, 한성컴퓨터 TFG27F14P IPS 144 게이밍  ...  한성컴퓨터 TFG27F14P IPS 144  일반적인 가성비 게이밍 모니터는 TN ...
# 21           포스픽 PC 배그, 롤 게임용 조립PC 컴퓨터 플래티넘 에디션 이용 후기  ...  포스픽 PC를 이용해보았다. 포스픽 PC는 요즘 떠오르고 있는 조립 PC 브랜드로 ...
# 22                            4K 작업도 문제없는 영상편집 컴퓨터 사양  ...  ​오늘은 프리미어 프로와 애프터 이펙트를 사용하기 위한 영상편집 컴퓨터를 소개합니다...
# 23  케이스만 한 달 고른 여자분. 화려한 '눈뽕' 컴퓨터! 80만원 가성비로 맞추는 법...  ...  ​2년 전쯤에~~ 프렉탈 디자인 케이스(무려12만원)로 하고 싶다고 해서 맞췄던 분...
# 24                        오토캐드, 스케치업 건축설계 인테리어 조립 컴퓨터  ...   Overview 인텔 10세대 i7 10700F로 무장한 최신 설계용 조립 PC....
# 25                            ARM 기반의 슈퍼컴퓨터 - 후지쯔 후카쿠  ...
# 26                                          게임용 조립컴퓨터  ...  조립컴퓨터​안녕하세요, 양컴입니다.오늘은 오로지 게이밍을 위해서 인텔 i7-1070...
# 27                        라이젠 3100으로 완성한 가성비 조립컴퓨터 견적  ...  라이젠 3100 + 지포스 GTX1650 SUPER 조합웬만한 작업과 게임에 대응하...
# 28  XIGMATEK ZEUS ARCTIC RGB 강화유리 튜닝구성 AMD 3600 조립컴퓨터  ...  안녕하세요~~용산 조립컴퓨터 전문매장  세븐컴피씨 입니다. 15년 동안  같은자리~...
# 29            인텔 i7 10700 F + GTX 1650조합 빠른 주식용컴퓨터 추천  ...  ​​​안녕하세요기나긴 장마가 끝나고더위가 시작되는 8월오래는 장마가 한 달 넘게 지...
# 30                             I5+1660S 빌드의 조립식컴퓨터 견적  ...  조립식컴퓨터​며칠째 주륵주륵 장마가 이어지고 습한날씨가 계속되고 있는 일상입니다. ...
# 31                          코로나와 전쟁, 전 세계 컴퓨터도 '연대'한다  ...  21세기 들어 인류에 가장 위협이 되는 존재가 나타났다. 코로나 바이러스 감염증-1...
# 32                       윈도우 컴퓨터 디스크 정리하기 - Cleanmgr+  ...  → 프로그램명 : Cleanmgr+→ 개발사 : https://www.builtby...
#
# [33 rows x 6 columns]

# %%
pd.set_option('display.max_colwidth', 500)
df = pd.DataFrame(columns=("title","data","date"))

# %%
df
# Out:
#     title   data   date
# 0       0      0      0
# 1      10     20     30
# 2      20     40     60
# 3      30     60     90
# 4      40     80    120
# ..    ...    ...    ...
# 995  9950  19900  29850
# 996  9960  19920  29880
# 997  9970  19940  29910
# 998  9980  19960  29940
# 999  9990  19980  29970
#
# [1000 rows x 3 columns]

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
for i in range(1000):
  df.loc[i] = [i*10, i*20, i*30]

# %%
for idx, data in df.iterrows():
  print(idx, data[0], data[1])
# Out:
# 0 0 0
# 1 10 20
# 2 20 40
# 3 30 60
# 4 40 80
# 5 50 100
# 6 60 120
# 7 70 140
# 8 80 160
# 9 90 180
# 10 100 200
# 11 110 220
# 12 120 240
# 13 130 260
# 14 140 280
# 15 150 300
# 16 160 320
# 17 170 340
# 18 180 360
# 19 190 380
# 20 200 400
# 21 210 420
# 22 220 440
# 23 230 460
# 24 240 480
# 25 250 500
# 26 260 520
# 27 270 540
# 28 280 560
# 29 290 580
# 30 300 600
# 31 310 620
# 32 320 640
# 33 330 660
# 34 340 680
# 35 350 700
# 36 360 720
# 37 370 740
# 38 380 760
# 39 390 780
# 40 400 800
# 41 410 820
# 42 420 840
# 43 430 860
# 44 440 880
# 45 450 900
# 46 460 920
# 47 470 940
# 48 480 960
# 49 490 980
# 50 500 1000
# 51 510 1020
# 52 520 1040
# 53 530 1060
# 54 540 1080
# 55 550 1100
