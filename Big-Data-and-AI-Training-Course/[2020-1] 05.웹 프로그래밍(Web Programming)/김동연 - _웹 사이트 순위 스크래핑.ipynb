# %% [markdown]
# # BeautyfulSoup 웹 사이트 순위 스크래핑
#
# * Alexa: https://www.alexa.com/topsites

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = 'https://www.alexa.com/topsites'
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url,'html.parser')
rank_df = pd.DataFrame(columns=('Rank','Site','Dailt Time on Site','Dailt Pageviews per Visitor','% of Traffic From Search','Total Sites Linking In'))

sites = soup.find_all('div',{'class':'tr site-listing'})

for site in sites:
  rank = site.find('div',{'class':'td'}).get_text()
  website = site.select('p > a')[0].get_text()
  infos = site.find_all('div',{'class':'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank,website,time,pageview,traffic,linking]

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total Sites Linking In
# 1     1           Google.com  ...                    0.40%              1,694,563
# 2     2          Youtube.com  ...                   15.40%              1,283,608
# 3     3            Tmall.com  ...                    0.90%                  4,077
# 4     4            Baidu.com  ...                    5.10%                122,794
# 5     5               Qq.com  ...                    3.00%                299,049
# 6     6         Facebook.com  ...                    8.30%              2,941,214
# 7     7             Sohu.com  ...                    1.60%                 33,799
# 8     8           Taobao.com  ...                    3.20%                 30,345
# 9     9      Login.tmall.com  ...                    0.60%                     83
# 10   10               360.cn  ...                    0.40%                 17,767
# 11   11           Amazon.com  ...                   19.90%                436,265
# 12   12            Yahoo.com  ...                    7.80%                388,348
# 13   13               Jd.com  ...                    1.40%                 10,065
# 14   14        Wikipedia.org  ...                   72.70%              1,018,649
# 15   15          Sina.com.cn  ...                    2.60%                 58,788
# 16   16            Weibo.com  ...                    2.00%                 82,581
# 17   17      Pages.tmall.com  ...                    0.30%                    105
# 18   18           Reddit.com  ...                   28.50%                215,018
# 19   19             Live.com  ...                   10.90%                 34,113
# 20   20              Zoom.us  ...                   15.80%                  2,717
# 21   21          Netflix.com  ...                    9.60%                 12,083
# 22   22        Xinhuanet.com  ...                    2.80%                 42,719
# 23   23          Okezone.com  ...                    6.40%                 13,671
# 24   24        Microsoft.com  ...                   28.10%                312,466
# 25   25        Instagram.com  ...                   13.60%                840,220
# 26   26               Vk.com  ...                    9.20%                182,111
# 27   27        Myshopify.com  ...                    3.30%                    123
# 28   28           Office.com  ...                    9.50%                  6,554
# 29   29           Alipay.com  ...                    1.40%                  4,143
# 30   30             Csdn.net  ...                    6.80%                  7,883
# 31   31          Yahoo.co.jp  ...                   12.50%                 64,571
# 32   32            Twitch.tv  ...                    6.70%                 11,642
# 33   33         Blogspot.com  ...                   33.30%                 12,518
# 34   34        Google.com.hk  ...                    3.10%                  9,381
# 35   35             Bing.com  ...                    6.00%                 50,352
# 36   36        Bongacams.com  ...                    8.60%                124,496
# 37   37            Zhanqi.tv  ...                    0.80%                    413
# 38   38             Panda.tv  ...                    0.80%                    400
# 39   39       Aliexpress.com  ...                   13.50%                 24,926
# 40   40             Ebay.com  ...                   15.90%                 88,074
# 41   41            Naver.com  ...                   10.10%                 51,711
# 42   42            Amazon.in  ...                   25.70%                  8,262
# 43   43  Microsoftonline.com  ...                    2.90%                    808
# 44   44         China.com.cn  ...                    1.10%                 16,663
# 45   45    Stackoverflow.com  ...                   74.50%                 31,571
# 46   46            Tianya.cn  ...                    1.00%                  7,160
# 47   47          Twitter.com  ...                   11.50%              2,144,285
# 48   48         Amazon.co.jp  ...                   16.00%                 55,149
# 49   49       Tribunnews.com  ...                   61.80%                 25,389
# 50   50       Chaturbate.com  ...                    9.80%                 59,543
#
# [50 rows x 6 columns]

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = 'https://www.alexa.com/topsites/countries/US'
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url,'html.parser')
rank_df = pd.DataFrame(columns=('Rank','Site','Dailt Time on Site','Dailt Pageviews per Visitor','% of Traffic From Search','Total Sites Linking In'))

sites = soup.find_all('div',{'class':'tr site-listing'})

for site in sites:
  rank = site.find('div',{'class':'td'}).get_text()
  website = site.select('p > a')[0].get_text()
  infos = site.find_all('div',{'class':'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank,website,time,pageview,traffic,linking]

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total Sites Linking In
# 1     1           Google.com  ...                    0.40%              1,694,563
# 2     2          Youtube.com  ...                   15.40%              1,283,608
# 3     3           Amazon.com  ...                   19.90%                436,265
# 4     4            Yahoo.com  ...                    7.80%                388,348
# 5     5         Facebook.com  ...                    8.30%              2,941,214
# 6     6           Reddit.com  ...                   28.50%                215,018
# 7     7              Zoom.us  ...                   15.80%                  2,717
# 8     8        Wikipedia.org  ...                   72.70%              1,018,649
# 9     9        Myshopify.com  ...                    3.30%                    123
# 10   10             Ebay.com  ...                   15.90%                 88,074
# 11   11          Netflix.com  ...                    9.60%                 12,083
# 12   12             Bing.com  ...                    6.00%                 50,352
# 13   13           Office.com  ...                    9.50%                  6,554
# 14   14             Live.com  ...                   10.90%                 34,113
# 15   15            Twitch.tv  ...                    6.70%                 11,642
# 16   16        Microsoft.com  ...                   28.10%                312,466
# 17   17            Chase.com  ...                    8.50%                  1,367
# 18   18        Instagram.com  ...                   13.60%                840,220
# 19   19       Chaturbate.com  ...                    9.80%                 59,543
# 20   20           Zillow.com  ...                   31.60%                 10,839
# 21   21              Cnn.com  ...                   21.70%                131,549
# 22   22  Microsoftonline.com  ...                    2.90%                    808
# 23   23          Walmart.com  ...                   28.60%                 20,374
# 24   24            Apple.com  ...                   36.80%                226,414
# 25   25       Aliexpress.com  ...                   13.50%                 24,926
# 26   26         Linkedin.com  ...                   13.90%                825,578
# 27   27             Etsy.com  ...                   20.50%                115,303
# 28   28          Dropbox.com  ...                    7.70%                 27,671
# 29   29          Nytimes.com  ...                   28.30%                190,542
# 30   30       Craigslist.org  ...                   22.50%                 16,715
# 31   31            Adobe.com  ...                   25.00%                334,054
# 32   32          Twitter.com  ...                   11.50%              2,144,285
# 33   33       Wellsfargo.com  ...                   11.50%                  2,458
# 34   34             Okta.com  ...                    2.90%                    267
# 35   35             Espn.com  ...                   12.00%                 10,937
# 36   36            Tmall.com  ...                    0.90%                  4,077
# 37   37       Livejasmin.com  ...                    3.70%                 12,706
# 38   38            Imgur.com  ...                    7.90%                259,351
# 39   39        Homedepot.com  ...                   44.50%                 13,949
# 40   40             Usps.com  ...                   23.30%                  8,877
# 41   41       Salesforce.com  ...                    5.90%                  5,242
# 42   42            Force.com  ...                    2.50%                  3,762
# 43   43             Hulu.com  ...                    9.60%                 12,385
# 44   44          Pornhub.com  ...                   26.10%                  4,912
# 45   45           Indeed.com  ...                   25.70%                  9,098
# 46   46               Ca.gov  ...                   31.10%                 47,772
# 47   47             Imdb.com  ...                   47.30%                169,287
# 48   48              Msn.com  ...                    7.50%                112,676
# 49   49    Stackoverflow.com  ...                   74.50%                 31,571
# 50   50        Amazonaws.com  ...                    6.90%                 66,038
#
# [50 rows x 6 columns]

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = 'https://www.alexa.com/topsites/countries/KR'
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url,'html.parser')
rank_df = pd.DataFrame(columns=('Rank','Site','Dailt Time on Site','Dailt Pageviews per Visitor','% of Traffic From Search','Total Sites Linking In'))

sites = soup.find_all('div',{'class':'tr site-listing'})

for site in sites:
  rank = site.find('div',{'class':'td'}).get_text()
  website = site.select('p > a')[0].get_text()
  infos = site.find_all('div',{'class':'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank,website,time,pageview,traffic,linking]

rank_df
# Out:
#    Rank               Site  ... % of Traffic From Search Total Sites Linking In
# 1     1         Google.com  ...                    0.40%              1,694,563
# 2     2          Naver.com  ...                   10.10%                 51,711
# 3     3        Youtube.com  ...                   15.40%              1,283,608
# 4     4           Daum.net  ...                    5.20%                 18,815
# 5     5        Tistory.com  ...                   25.20%                 10,338
# 6     6          Tmall.com  ...                    0.90%                  4,077
# 7     7          Kakao.com  ...                    8.30%                 14,151
# 8     8       Google.co.kr  ...                   11.10%                  4,905
# 9     9         Amazon.com  ...                   19.90%                436,265
# 10   10       Facebook.com  ...                    8.30%              2,941,214
# 11   11           Sohu.com  ...                    1.60%                 33,799
# 12   12             Qq.com  ...                    3.00%                299,049
# 13   13          Namu.wiki  ...                   22.60%                    117
# 14   14        Coupang.com  ...                   13.50%                    486
# 15   15        Netflix.com  ...                    9.60%                 12,083
# 16   16    Login.tmall.com  ...                    0.60%                     83
# 17   17      Wikipedia.org  ...                   72.70%              1,018,649
# 18   18         Taobao.com  ...                    3.20%                 30,345
# 19   19             360.cn  ...                    0.40%                 17,767
# 20   20             Jd.com  ...                    1.40%                 10,065
# 21   21          Baidu.com  ...                    5.10%                122,794
# 22   22       Dcinside.com  ...                   18.60%                    879
# 23   23      Microsoft.com  ...                   28.10%                312,466
# 24   24    Pages.tmall.com  ...                    0.30%                    105
# 25   25          Yahoo.com  ...                    7.80%                388,348
# 26   26          Twitch.tv  ...                    6.70%                 11,642
# 27   27      Gmarket.co.kr  ...                   16.10%                  2,450
# 28   28          Apple.com  ...                   36.80%                226,414
# 29   29      Instagram.com  ...                   13.60%                840,220
# 30   30          Weibo.com  ...                    2.00%                 82,581
# 31   31        Sina.com.cn  ...                    2.60%                 58,788
# 32   32  Stackoverflow.com  ...                   74.50%                 31,571
# 33   33          Nexon.com  ...                   12.00%                    782
# 34   34           Nate.com  ...                    5.40%                  2,738
# 35   35          Adobe.com  ...                   25.00%                334,054
# 36   36          Donga.com  ...                   17.10%                  4,827
# 37   37           Bing.com  ...                    6.00%                 50,352
# 38   38         Office.com  ...                    9.50%                  6,554
# 39   39          Yna.co.kr  ...                   13.90%                    595
# 40   40         11st.co.kr  ...                    3.70%                  1,419
# 41   41           Ebay.com  ...                   15.90%                 88,074
# 42   42       Amazon.co.uk  ...                   19.50%                 66,929
# 43   43        Ruliweb.com  ...                   16.00%                    541
# 44   44          Joins.com  ...                   23.60%                  5,987
# 45   45        Inven.co.kr  ...                   32.80%                  1,336
# 46   46  Theepochtimes.com  ...                   13.20%                 22,840
# 47   47      Afreecatv.com  ...                    6.00%                    551
# 48   48         Chosun.com  ...                   23.80%                  8,165
# 49   49      Auction.co.kr  ...                   11.70%                  1,485
# 50   50      Ppomppu.co.kr  ...                   10.90%                    892
#
# [50 rows x 6 columns]
