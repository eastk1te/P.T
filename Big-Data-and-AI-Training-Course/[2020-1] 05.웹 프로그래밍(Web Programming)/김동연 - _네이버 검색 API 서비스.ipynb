# %% [markdown]
# # 네이버 검색 API 서비스

# %% [markdown]
# ## 네이버 서비스 API 신청
#
# 1. 네이버 개발자센터: https://developers.naver.com/products/search/
# 2. 어플리케이션 등록
# 3. 클라이언트 ID/SECRET 확인

# %% [markdown]
# ## NAVER 서비스 API 종류
# | 항목 | 주소                                         |
# |------|----------------------------------------------|
# |블로그| https://openapi.naver.com/v1/search/blog.json |
# |뉴스　| https://openapi.naver.com/v1/search/news.json |
# | 책　 | https://openapi.naver.com/v1/search/book.json|
# | 성인 검색어 판별|　https://openapi.naver.com/v1/search/adult.json|
# | 백과사전| https://openapi.naver.com/v1/search/encyc.json|
# | 영화| https://openapi.naver.com/v1/search/movie.json|
# | 카페글 |https://openapi.naver.com/v1/search/cafearticle.json|
# | 지식in| https://openapi.naver.com/v1/search/kin.json|
# | 지역 | https://openapi.naver.com/v1/search/local.json|
# | 오타변환 | https://openapi.naver.com/v1/search/errata.json|
# | 웹문서 | https://openapi.naver.com/v1/search/webkr.json|
# | 이미지 | https://openapi.naver.com/v1/search/image.json|
# | 쇼핑 | https://openapi.naver.com/v1/search/shop.json|
# | 전문자료 | https://openapi.naver.com/v1/search/doc.json|

# %% [markdown]
# ## 네이버 웹문서 검색 API

# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

client_id = "x2ISQJOSc31vYTRLQKRD"
client_secret = "cQChHlFvN5"

query = urllib.parse.quote(input('검색질의 : '))
idx= 0 
display=100
start = 1
end=1000

web_df = pd.DataFrame(columns=('Titel','Link','Description'))

for start_index in range(start,end,display):
  url = "https://openapi.naver.com/v1/search/webkr?query=" + query \
        + '&display=' + str(display) \
        + '&start=' + str(start_index)


  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0,len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag,'',items[item_index]['description'])
        web_df.loc[idx] = [title,link,description]
        idx += 1

  else:
    print("Error Code:" + rescode)

web_df
# Out:
# 검색질의 : 컴퓨터
#                           Titel  ...                                        Description
# 0                    컴퓨터 - 나무위키  ...  개인용 컴퓨터에 대한 내용은 PC 문서를 참조하십시오. 올해의 인물 (1980년대)...
# 1                  슈퍼컴퓨터 - 나무위키  ...  가장 빠른 슈퍼컴퓨터 연혁 4.2. 대한민국의 슈퍼컴퓨터 도입 4.2.1. 기상청 ...
# 2                          TG삼보  ...                  컴퓨터, 모니터, 노트북 제조판매 등 제품소개, AS 안내.
# 3                          주연테크  ...  주연테크 회사소개 및 컴퓨터,PC,데스크탑,모니터,노트북,태블릿,TV,CCTV 등 ...
# 4                        한글과컴퓨터  ...  한컴오피스, 씽크프리, 전자책, 앱북, 솔루션 제품 체험판, 뷰어 다운로드 및 고객...
# ..                          ...  ...                                                ...
# 195                  컴퓨터학부 특강안내  ...  【 컴퓨터학부 특강안내 】 컴퓨터학부 조회 : 132 등록일 : 2019-11-21...
# 196  공지사항 &gt;학부공지사항 &gt; 컴퓨터학부  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 95 등록일 : 2019-...
# 197           컴퓨터학부 현장실습(견학) 안내  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 495 등록일 : 2019...
# 198  공지사항 &gt;학부공지사항 &gt; 컴퓨터학부  ...  【 컴퓨터학부 특강안내 】 컴퓨터학부 조회 : 97 등록일 : 2019-11-21 ...
# 199           컴퓨터학부 현장실습(견학) 안내  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 122 등록일 : 2019...
#
# [200 rows x 3 columns]

# %% [markdown]
# ## 네이버 지식iN 검색 API

# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

client_id = "x2ISQJOSc31vYTRLQKRD"
client_secret = "cQChHlFvN5"

query = urllib.parse.quote(input('검색질의 : '))
idx= 0 
display=100
start = 1
end=1000
sort = 'sim'

kin_df = pd.DataFrame(columns=('Titel','Link','Description'))

for start_index in range(start,end,display):
  url = "https://openapi.naver.com/v1/search/kin?query=" + query \
        + '&display=' + str(display) \
        + '&start=' + str(start_index) \
        + '&sort=' + sort


  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0,len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag,'',items[item_index]['description'])
        kin_df.loc[idx] = [title,link,description]
        idx += 1

  else:
    print("Error Code:" + rescode)

kin_df
# Out:
# 검색질의 : 컴퓨터
#                 Titel  ...                                        Description
# 0      학점은행제 컴퓨터공학..?  ...  안녕하세요 학점은행제 컴퓨터공학을 시작하려고 하는데요. 제가 직장인인데 학점은행제 ...
# 1       학점은행제 컴퓨터공학 좀  ...  제가 컴퓨터공학 분야로 알아보고 있는데 학점은행제 컴퓨터공학 쪽으로 가능한건가요? ...
# 2        학점은행제 컴퓨터공학*  ...  ... 그래서 학점은행제 컴퓨터공학 해보려고 하는데요. 직장 다니면서 학점은행제 컴...
# 3             조립식컴퓨터랑  ...  조립식컴퓨터랑 그냥 컴퓨터랑 성능 면에서 차이가 있나요? 질문자님을 뵙게 되어 감사...
# 4        학점은행제 컴퓨터공학을  ...  학점은행제 컴퓨터공학을 이수하면 학점은행제 컴퓨터공학 학위가 나오나요? 대학교가 아...
# ..                ...  ...                                                ...
# 995      전자컴퓨터공학과에 대해  ...  제 꿈이 프로그래머인데 희망하는 대학에 컴퓨터공학과는 없고 전자컴퓨터공학부,전자정보...
# 996  조립식컴퓨터 vs 브랜드컴퓨터  ...  제가 컴퓨터를 구매하기에 앞서, 요즘 조립식컴퓨터를 사람들이 많이 사용하다는 얘기를...
# 997            컴퓨터 질문  ...  ... 확실하진않지만 컴퓨터를 바꿀수도잇어 질문합니다. 일단 저는 롤이라는 게임을합...
# 998          컴퓨터관련 학과  ...  컴퓨터관련 학과를 알아보는 고3입니다. 질문이 몇개 있는데 답변해주시면 감사하겠습니...
# 999    정보보호 영재와 컴퓨터학원  ...  이번에 컴퓨터공부(IT)에 관심이 있어 컴퓨터공부를 시작하려는 예비 고1입니다 이번...
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## 네이버 뉴스 검색 API

# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

client_id = "x2ISQJOSc31vYTRLQKRD"
client_secret = "cQChHlFvN5"

query = urllib.parse.quote(input('검색질의 : '))
idx= 0 
display=100
start = 1
end=1000
sort = 'sim'

news_df = pd.DataFrame(columns=('Titel','Original Link','Link','Description','Publication Date'))

for start_index in range(start,end,display):
  url = "https://openapi.naver.com/v1/search/news?query=" + query \
        + '&display=' + str(display) \
        + '&start=' + str(start_index) \
        + '&sort=' + sort


  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0,len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        original_link = items[item_index]['originallink']
        link = items[item_index]['link']
        description = re.sub(remove_tag,'',items[item_index]['description'])
        pub_date = items[item_index]['pubDate']
        news_df.loc[idx] = [title,original_link,link,description,pub_date]
        idx += 1

  else:
    print("Error Code:" + rescode)

news_df
# Out:
# 검색질의 : 컴퓨터
#                                      Titel  ...                 Publication Date
# 0              한글과컴퓨터, 신생 스타트업에 한컴오피스 무상공급  ...  Mon, 10 Aug 2020 14:04:00 +0900
# 1           한글과컴퓨터, 신생 스타트업 대상 한컴오피스 무상 공급  ...  Mon, 10 Aug 2020 11:36:00 +0900
# 2            한글과컴퓨터, 스타트업에 한컴오피스 1년간 무상 제공  ...  Mon, 10 Aug 2020 10:03:00 +0900
# 3            한글과컴퓨터, 신생 스타트업 대상 한컴오피스 무상공급  ...  Mon, 10 Aug 2020 10:58:00 +0900
# 4            한글과컴퓨터, 신생 스타트업 대상 한컴오피스 무상공급  ...  Mon, 10 Aug 2020 15:40:00 +0900
# ..                                     ...  ...                              ...
# 995    와이즈유, AI·컴퓨터공학과 내년 신설 개편···첨단학과로 주목  ...  Wed, 20 May 2020 10:44:00 +0900
# 996                 과기정통부, 슈퍼컴퓨터 CPU 개발 추진  ...  Thu, 26 Mar 2020 11:29:00 +0900
# 997  오순영 한글과컴퓨터 CTO, '2020 세계인공지능회의' 연사 참여  ...  Thu, 09 Jul 2020 10:18:00 +0900
# 998         영진전문대, 컴퓨터정보계열 91.1% 비대면 수업 만족  ...  Mon, 29 Jun 2020 09:34:00 +0900
# 999         신한생명, 온라인 개학 소외아동에 컴퓨터 100대 지원  ...  Mon, 13 Apr 2020 09:48:00 +0900
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## 네이버 블로그 검색 API

# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

client_id = "x2ISQJOSc31vYTRLQKRD"
client_secret = "cQChHlFvN5"

query = urllib.parse.quote(input('검색질의 : '))
idx= 0 
display=100
start = 1
end=1000
sort = 'sim'

blog_df = pd.DataFrame(columns=('Titel','Link','Description', 'Blogger Name','Blogger Link','Post Date'))

for start_index in range(start,end,display):
  url = "https://openapi.naver.com/v1/search/blog?query=" + query \
        + '&display=' + str(display) \
        + '&start=' + str(start_index) \
        + '&sort=' + sort


  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0,len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag,'',items[item_index]['description'])
        blogger_name = items[item_index]['bloggername']
        blogger_link = items[item_index]['bloggerlink']
        post_date = items[item_index]['postdate']
        blog_df.loc[idx] = [title,link,description,blogger_name,blogger_link,post_date]
        idx += 1

  else:
    print("Error Code:" + rescode)

blog_df
# Out:
# 검색질의 : 컴퓨터
#                                       Titel  ... Post Date
# 0                            할수있다 컴퓨터공학과 편입  ...  20200808
# 1                      국비지원컴퓨터학원 현명한 선택이 필수  ...  20200720
# 2                        컴퓨터학원 국비지원으로 배웠어요!  ...  20200423
# 3            한성컴퓨터 가성비 노트북 올데이롱 TFX255S 사용기  ...  20200806
# 4                     강남컴퓨터학원 전문가로 성장하는 과정!  ...  20200708
# ..                                      ...  ...       ...
# 995    3DSMAX / RHINO / MAYA 고사양 3D 모델링 컴퓨터  ...  20200213
# 996  R) 가성비 좋은 컴퓨터의자 추천! 린백 LB70L 게이밍의자!! ①  ...  20200401
# 997                    GTX1660TI 게임용 조립식컴퓨터  ...  20190531
# 998          살펴보기(ft.안양컴퓨터학원상담후기포함-영상편집과정).  ...  20200702
# 999                       한성컴퓨터 TFX255 올데이롱  ...  20190920
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## 네이버 책 검색 API

# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

client_id = "x2ISQJOSc31vYTRLQKRD"
client_secret = "cQChHlFvN5"

query = urllib.parse.quote(input('검색질의 : '))
idx= 0 
display=100
start = 1
end=1000
sort = 'sim'

book_df = pd.DataFrame(columns=('Titel','Link','Image','Author','Price','Discount','Publisher','ISBN','Description','Publication Date'))

for start_index in range(start,end,display):
  url = "https://openapi.naver.com/v1/search/book?query=" + query \
        + '&display=' + str(display) \
        + '&start=' + str(start_index) \
        + '&sort=' + sort


  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0,len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']
        author = items[item_index]['author']
        price = items[item_index]['price']
        discount = items[item_index]['discount']
        publisher = items[item_index]['publisher']
        isbn = items[item_index]['isbn']
        description = re.sub(remove_tag,'',items[item_index]['description'])
        pubdate = items[item_index]['pubdate']
        book_df.loc[idx] = [title,link,image,author,price,discount,publisher,isbn,description,pubdate]
        idx += 1

  else:
    print("Error Code:" + rescode)

book_df
# Out:
# 검색질의 : 컴퓨터
#                                                  Titel  ... Publication Date
# 0    시나공 총정리 컴퓨터활용능력 1급 필기 (핵심요약+기출문제+모의고사+암기프로그램+기...  ...         20190909
# 1                              시나공 컴퓨터활용능력 2급실기 (2020)  ...         20191008
# 2                              시나공 컴퓨터활용능력1급 실기 (2020)  ...         20191010
# 3    시나공 총정리 컴퓨터활용능력 2급 필기 (핵심요약+기출문제+모의고사+암기프로그램+기...  ...         20190909
# 4    시나공 컴퓨터활용능력 1급 필기 (필수암기집+동영상강의+암기프로그램+기출CBT,2020)  ...         20191028
# ..                                                 ...  ...              ...
# 995             컴퓨터 달인 되기 101가지 비법 (우리 부모님 컴퓨터 초보 탈출기)  ...         20090610
# 996                              미래컴퓨터를 줍다 2 (초갑질 기업물)  ...         20180320
# 997                         부모님의 첫번째 컴퓨터+인터넷 책 (윈도우 7)  ...         20110627
# 998                                [빅북] IoT 시대의 스마트컴퓨터  ...         20190109
# 999                                     슈퍼컴퓨터를 사랑한 슈퍼맨  ...         20150811
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## 네이버 영화 검색 API

# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

client_id = "x2ISQJOSc31vYTRLQKRD"
client_secret = "cQChHlFvN5"

query = urllib.parse.quote(input('검색질의 : '))
idx= 0 
display=100
start = 1
end=1000
sort = 'sim'

movie_df = pd.DataFrame(columns=('Titel','Link','Image','Subtitle','Publication Date','Director','Actor','User Rating'))

for start_index in range(start,end,display):
  url = "https://openapi.naver.com/v1/search/movie?query=" + query \
        + '&display=' + str(display) \
        + '&start=' + str(start_index) \
        + '&sort=' + sort


  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0,len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']
        subtitle = items[item_index]['subtitle']
        pub_date = items[item_index]['pubDate']

        director = items[item_index]['director']
        actor = items[item_index]['actor']
        user_rating = items[item_index]['userRating']
        movie_df.loc[idx] = [title,link,image,subtitle,pub_date,director,actor,user_rating]
        idx += 1

  else:
    print("Error Code:" + rescode)

movie_df
# Out:
# 검색질의 : 아이언맨
#                    Titel  ... User Rating
# 0        엘론 머스크: 리얼 아이언맨  ...        0.00
# 1                   아이언맨  ...        4.95
# 2     아이언맨 &amp; 캡틴 아메리카  ...        9.00
# 3                 아이언맨 3  ...        8.86
# 4    아이언 맨: 라이즈 오브 테크노보어  ...        3.28
# ..                   ...  ...         ...
# 125           인빈서블 아이언 맨  ...        7.24
# 126     특수공작원 아이언맨 - 시리즈  ...        7.63
# 127           특수공작원 아이언맨  ...        9.00
# 128                아이언 맨  ...        5.37
# 129                아이언 맨  ...        7.54
#
# [130 rows x 8 columns]

# %% [markdown]
# ## 네이버 쇼핑 검색 API

# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

client_id = "x2ISQJOSc31vYTRLQKRD"
client_secret = "cQChHlFvN5"

query = urllib.parse.quote(input('검색질의 : '))
idx= 0 
display=100
start = 1
end=1000
sort = 'sim'
shop_df = pd.DataFrame(columns=('Titel','Link','Image','Low Price','High Price','Mall Name','Product ID','Product Type','Maker','Brand'))

for start_index in range(start,end,display):
  url = "https://openapi.naver.com/v1/search/shop?query=" + query \
        + '&display=' + str(display) \
        + '&start=' + str(start_index) \
        + '&sort=' + sort


  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0,len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']
        low_price = items[item_index]['lprice']
        high_price = items[item_index]['hprice']
        mall_name = items[item_index]['mallName']
        product_id = items[item_index]['productId']
        product_type = items[item_index]['productType']
        maker = items[item_index]['maker']
        brand = items[item_index]['brand']
        
        shop_df.loc[idx] = [title,link,image,low_price,high_price,mall_name,product_id,product_type,maker,brand]
        idx += 1

  else:
    print("Error Code:" + rescode)

shop_df
# Out:
# 검색질의 : 컴퓨터
#                                          Titel  ...  Brand
# 0                       로스트아크 서든어택 롤 배틀그라운드컴퓨터  ...
# 1                              배틀그라운드 오버워치조립PC  ...
# 2                        삼성전자 삼성 DM530ABE-L58A  ...     삼성
# 3            아싸컴 프리미엄 게이밍 i5-9400F + 외장형 그래픽카드  ...    아싸컴
# 4                            LG전자 24V50N-GR56K  ...   LG전자
# ..                                         ...  ...    ...
# 995                 프리플로우 GAMING CREATOR 9928S  ...  프리플로우
# 996             DELL 보스트로 3671MT RV3671-0001KR  ...   보스트로
# 997  셀텍 Cool Slim ODD LP Z370 i3 WiFi 180W SSD  ...     셀텍
# 998             셀텍 Thin H310 180W i5-8400T M.2  ...     셀텍
# 999                           한성컴퓨터 TFG AX3727  ...  한성컴퓨터
#
# [1000 rows x 10 columns]
