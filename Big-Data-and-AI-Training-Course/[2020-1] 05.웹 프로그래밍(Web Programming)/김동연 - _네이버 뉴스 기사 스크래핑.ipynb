# %% [markdown]
# # BeautyfulSoup 네이버 뉴스 기사 스크래핑

# %% [markdown]
# ## 뉴스 기사 스크래핑 함수 정의

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import pandas as pd



def get_news(query,page_num=10):
  
  news_df = pd.DataFrame(columns=('Title','Link','Press','DateTime','Article'))
  idx = 0

  url_query = quote(query)
  url = 'https://search.naver.com/search.naver?&where=news&sm=nws_hty&query=' + url_query
  

  for _ in range(0,page_num):

    search_url = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(search_url,'html.parser')
    links = soup.find_all('dd',{'class':'txt_inline'})

    for link in links:
      press = link.find('span',{'class':'_sp_each_source'}).get_text()
      news_url = link.find('a').get('href')
      

      if (news_url == '#'):
        continue
      else:
        news_link = urllib.request.urlopen(news_url).read()
        news_html = BeautifulSoup(news_link,'html.parser')

        try:
          title = news_html.find('h3',{'id':'articleTitle'}).get_text()
          datetime = news_html.find('span',{'class':'t11'}).get_text()
          article = news_html.find('div',{'id':'articleBodyContents'}).get_text()
          article = article.replace('// flash 오류를 우회하기 위한 함수 추가','')
          article = article.replace('function _flash_removeCallback() {}','')
          article = article.replace('\n','')
          article = article.replace('\t','')
        except:
          continue
          
        news_df.loc[idx] = [title,news_url,press,datetime,article]
        idx += 1
        print('#',end='')

    try:
      next = soup.find('a',{'class':'next'}).get('href')
      url = 'https://search.naver.com/search.naver' + next
    except:
      break

  return news_df

# %% [markdown]
# ## 뉴스 기사 스크래핑 실행

# %%
query = input('검색질의 : ')
news_df = get_news(query,3)
print('Done')
# Out:
# 검색질의 : 수해복구
# ##########################Done

# %%
news_df
# Out:
#                                                Title  ...                                            Article
# 0                국내 최대 인공지능 전시회 'AI 코리아 2020' 부산서 개최  ...  [부산CBS 강동수 기자]부산 대표 마이스 시설인 벡스코에서 국내 최대 규모 인공지...
# 1  국내 최대 규모 인공지능 전시회 ‘AI KOREA 2020’ AI 중심도시 부산에서 개최  ...  지방자치단체가 주최하는 전국 최초의 AI 전시회인 ‘AI KOREA 2020’이 오...
# 2                      3차원부터 인공지능까지… 코로나에 대처하는 의류 中企  ...  의류 중견·중소기업들이 코로나에 대처하기 위해 비대면(非對面)에 뛰어들고 있다. 3...
# 3           [AI 사피엔스 시대]ETRI 국가지능화 비전 구현 핵심, 인공지능연구소  ...  한국전자통신연구원(ETRI)한국전자통신연구원(ETRI)의 인공지능연구소(이하 AI ...
# 4                           인공지능 활용 초등학교부터 '수포자' 막는다  ...  교육부·교육감협의회 '교육안전망 강화방안' 발표AI로 초등 국·영·수 지원…중하위권...
#
# [5 rows x 5 columns]

# %%
news_df['Article']
# Out:
# 0     산사태 피해 복구작업 하는 심상정-류호정 - 정의당 심상정 대표와 류호정 의원이 7...
# 1     [한국경제TV 이지효 기자]국내 양대 포털이 장기간 집중 폭우로 인한 피해 복구에 ...
# 2     피해 지역 신속한 복구 위한 성금 기탁 및 지원 실시한화생명·한화손보, 집중호우 피...
# 3     전국재해구호협회 통해 구호물품 지원에 사용CJ제일제당, 햇반 간편식 제품 1만200...
# 4     [파이낸셜뉴스]한국타이어앤테크놀로지(한국타이어)가 집중호우 피해 복구와 이재민 지원...
# 5     (지디넷코리아=정진호  기자)한화그룹이 최근 장기간 이어진 집중호우로 피해를 입은 ...
# 6     한국감정원 사옥. © News1 © News1 진희정 기자(서울=뉴스1) 이동희 기...
# 7     곡성군·하동군에도 녹차제품 위문품 전달[김동언 기자(=보성)(kde3200@daum...
# 8     한국토요타자동차는 희망브리지 전국재해구호협회를 통해 수해 복구 성금 1억 원을 기부...
# 9     네이버 15억·카카오 20억 기부…전국민 모금활동도 시작[아이뉴스24 윤지혜 기자]...
# 10    김태년 "재난지원금 현실화…내일 고위 당정서 논의"(서울·음성=연합뉴스) 이대희 홍...
# 11    [파이낸셜뉴스]한국타이어앤테크놀로지(한국타이어)가 집중호우 피해 복구와 이재민 지원...
# 12    (지디넷코리아=정진호  기자)한화그룹이 최근 장기간 이어진 집중호우로 피해를 입은 ...
# 13    [파이낸셜뉴스]한국감정원은 11일 집중호우로 피해를 입은 지역의 신속한 복구와 주민...
# 14    포스코 대치동 사옥 전경. [사진= 포스코그룹 제공]포스코그룹은 10일 수해 복구 ...
# 15    전국민에 12兆 이상 퍼붓더니···정작 수해 대응할 재정여력 고갈더불어민주당 이해찬...
# 16     더불어민주당 김태년 원내대표 등 민주당 원내지도부는 오늘(11일) 충북 음성 수해...
# 17    곡성군·하동군에도 녹차제품 위문품 전달[김동언 기자(=보성)(kde3200@daum...
# 18    한국토요타자동차는 희망브리지 전국재해구호협회를 통해 수해 복구 성금 1억 원을 기부...
# 19    "靑이 먼저 나서 답할 문제는 아니다"권성동 "4대강 디스말고 보(洑) 파괴하라"에...
# 20    여야 모두 "추경 편성해야"국회 본회의장 ⓒ시사저널 박은숙계속되는 장맛비로 피해가 ...
# 21    (서울=연합뉴스) 윤보람 기자 = 한국전력은 11일 집중 호우에 따른 피해 복구를 ...
# 22    민주당 이해찬 “긴급논의” 밝혀박광온 “국회가 선제적으로 검토”통합·정의·국민의당도...
# 23    주택 164가구·농경지 604㏊ 침수…피해 누계 216억원작년 강수량 933.5㎜보...
# 24    태영호 의원.탈북민 출신 태영호 미래통합당 의원이 사진 한 장으로 대중 인지도와 호...
# 25    "조금이나마 위로와 도움이 되길 기원"[아이뉴스24 이연춘 기자] 최근 집중호우로 ...
# Name: Article, dtype: object
